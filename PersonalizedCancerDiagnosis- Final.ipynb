# %% [markdown]
# <p style="font-size:36px;text-align:center"> <b>Personalized cancer diagnosis</b> </p>

# %% [markdown]
# <h1>1. Business Problem</h1>

# %% [markdown]
# <h2>1.1. Description</h2>

# %% [markdown]
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/ </p>
# <p> Data: Memorial Sloan Kettering Cancer Center (MSKCC)</p>
# <p> Download training_variants.zip and training_text.zip from Kaggle.</p>
#
# <h6> Context:</h6>
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/discussion/35336#198462</p>
#
# <h6> Problem statement : </h6>
# <p> Classify the given genetic variations/mutations based on evidence from text-based clinical literature. </p>

# %% [markdown]
# <h2>1.2. Source/Useful Links</h2>

# %% [markdown]
#  Some articles and reference blogs about the problem statement

# %% [markdown]
# 1. https://www.forbes.com/sites/matthewherper/2017/06/03/a-new-cancer-drug-helped-almost-everyone-who-took-it-almost-heres-what-it-teaches-us/#2a44ee2f6b25
# 2. https://www.youtube.com/watch?v=UwbuW7oK8rk
# 3. https://www.youtube.com/watch?v=qxXRKVompI8

# %% [markdown]
# <h2>1.3. Real-world/Business objectives and constraints.</h2>

# %% [markdown]
# * No low-latency requirement.
# * Interpretability is important.
# * Errors can be very costly.
# * Probability of a data-point belonging to each class is needed.

# %% [markdown]
# <h1>2. Machine Learning Problem Formulation</h1>

# %% [markdown]
# <h2>2.1. Data</h2>

# %% [markdown]
# <h3>2.1.1. Data Overview</h3>

# %% [markdown]
# - Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/data
# - We have two data files: one conatins the information about the genetic mutations and the other contains the clinical evidence (text) that  human experts/pathologists use to classify the genetic mutations.
# - Both these data files are have a common column called ID
# - <p>
#     Data file's information:
#     <ul>
#         <li>
#         training_variants (ID , Gene, Variations, Class)
#         </li>
#         <li>
#         training_text (ID, Text)
#         </li>
#     </ul>
# </p>

# %% [markdown]
# <h3>2.1.2. Example Data Point</h3>

# %% [markdown]
# <h6>training_variants</h6>
# <hr>
# ID,Gene,Variation,Class<br>
# 0,FAM58A,Truncating Mutations,1 <br>
# 1,CBL,W802*,2 <br>
# 2,CBL,Q249E,2 <br>
# ...
#
# <h6> training_text</h6>
# <hr>
# ID,Text <br>
# 0||Cyclin-dependent kinases (CDKs) regulate a variety of fundamental cellular processes. CDK10 stands out as one of the last orphan CDKs for which no activating cyclin has been identified and no kinase activity revealed. Previous work has shown that CDK10 silencing increases ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2)-driven activation of the MAPK pathway, which confers tamoxifen resistance to breast cancer cells. The precise mechanisms by which CDK10 modulates ETS2 activity, and more generally the functions of CDK10, remain elusive. Here we demonstrate that CDK10 is a cyclin-dependent kinase by identifying cyclin M as an activating cyclin. Cyclin M, an orphan cyclin, is the product of FAM58A, whose mutations cause STAR syndrome, a human developmental anomaly whose features include toe syndactyly, telecanthus, and anogenital and renal malformations. We show that STAR syndrome-associated cyclin M mutants are unable to interact with CDK10. Cyclin M silencing phenocopies CDK10 silencing in increasing c-Raf and in conferring tamoxifen resistance to breast cancer cells. CDK10/cyclin M phosphorylates ETS2 in vitro, and in cells it positively controls ETS2 degradation by the proteasome. ETS2 protein levels are increased in cells derived from a STAR patient, and this increase is attributable to decreased cyclin M levels. Altogether, our results reveal an additional regulatory mechanism for ETS2, which plays key roles in cancer and development. They also shed light on the molecular mechanisms underlying STAR syndrome.Cyclin-dependent kinases (CDKs) play a pivotal role in the control of a number of fundamental cellular processes (1). The human genome contains 21 genes encoding proteins that can be considered as members of the CDK family owing to their sequence similarity with bona fide CDKs, those known to be activated by cyclins (2). Although discovered almost 20 y ago (3, 4), CDK10 remains one of the two CDKs without an identified cyclin partner. This knowledge gap has largely impeded the exploration of its biological functions. CDK10 can act as a positive cell cycle regulator in some cells (5, 6) or as a tumor suppressor in others (7, 8). CDK10 interacts with the ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2) transcription factor and inhibits its transcriptional activity through an unknown mechanism (9). CDK10 knockdown derepresses ETS2, which increases the expression of the c-Raf protein kinase, activates the MAPK pathway, and induces resistance of MCF7 cells to tamoxifen (6). ...

# %% [markdown]
# <h2>2.2. Mapping the real-world problem to an ML problem</h2>

# %% [markdown]
# <h3>2.2.1. Type of Machine Learning Problem</h3>

# %% [markdown]
# <p>
#
#             There are nine different classes a genetic mutation can be classified into => Multi class classification problem
#
#
#
# </p>

# %% [markdown]
# <h3>2.2.2. Performance Metric</h3>

# %% [markdown]
# Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment#evaluation
#
# Metric(s):
# * Multi class log-loss
# * Confusion matrix

# %% [markdown]
# <h3>2.2.3. Machine Learing Objectives and Constraints</h3>

# %% [markdown]
# <p> Objective: Predict the probability of each data-point belonging to each of the nine classes.
# </p>
# <p> Constraints:
# </p>
# * Interpretability
# * Class probabilities are needed.
# * Penalize the errors in class probabilites => Metric is Log-loss.
# * No Latency constraints.

# %% [markdown]
# <h2>2.3. Train, CV and Test Datasets</h2>

# %% [markdown]
#  Split the dataset randomly into three parts train, cross validation and test with 64%,16%, 20% of data respectively

# %% [markdown]
# <h1>3. Exploratory Data Analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from imblearn.over_sampling import SMOTE
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings("ignore")

from mlxtend.classifier import StackingClassifier
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# <h2>3.1. Reading Data</h2>

# %% [markdown]
# <h3>3.1.1. Reading Gene and Variation Data</h3>

# %%
data = pd.read_csv('training_variants')
print('Number of data points : ', data.shape[0])
print('Number of features : ', data.shape[1])
print('Features : ', data.columns.values)
data.head()
# Out:
# Number of data points :  3321
# Number of features :  4
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %% [markdown]
# <p>
#     training/training_variants is a comma separated file containing the description of the genetic mutations used for training. <br>
#     Fields are
#     <ul>
#         <li><b>ID : </b>the id of the row used to link the mutation to the clinical evidence</li>
#         <li><b>Gene : </b>the gene where this genetic mutation is located </li>
#         <li><b>Variation : </b>the aminoacid change for this mutations </li>
#         <li><b>Class :</b> 1-9 the class this genetic mutation has been classified on</li>
#     </ul>

# %% [markdown]
# <h3>3.1.2. Reading Text Data</h3>

# %%
# note the seprator in this file
data_text =pd.read_csv("training_text",sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)
print('Number of data points : ', data_text.shape[0])
print('Number of features : ', data_text.shape[1])
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# Number of data points :  3321
# Number of features :  2
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# <h3>3.1.3. Preprocessing of text</h3>

# %%
# loading stop words from nltk library
stop_words = set(stopwords.words('english'))


def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
        
        data_text[column][index] = string

# %%
#text processing stage.
start_time = time.clock()
for index, row in data_text.iterrows():
    if type(row['TEXT']) is str:
        nlp_preprocessing(row['TEXT'], index, 'TEXT')
    else:
        print("there is no text description for id:",index)
print('Time took for preprocessing the text :',time.clock() - start_time, "seconds")
# Out:
# there is no text description for id: 1109
# there is no text description for id: 1277
# there is no text description for id: 1407
# there is no text description for id: 1639
# there is no text description for id: 2755
# Time took for preprocessing the text : 211.28222849999997 seconds

# %%
#merging both gene_variations and text data based on ID
result = pd.merge(data, data_text,on='ID', how='left')
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %%
result[result.isnull().any(axis=1)]
# Out:
#         ID    Gene             Variation  Class TEXT
# 1109  1109   FANCA                S1088F      1  NaN
# 1277  1277  ARID5B  Truncating Mutations      1  NaN
# 1407  1407   FGFR3                 K508M      6  NaN
# 1639  1639    FLT1         Amplification      6  NaN
# 2755  2755    BRAF                 G596C      7  NaN

# %%
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] +' '+result['Variation']

# %%
result[result['ID']==1109]
# Out:
#         ID   Gene Variation  Class          TEXT
# 1109  1109  FANCA    S1088F      1  FANCA S1088F

# %% [markdown]
# ### Feature Engineering - Replacing Variations with count 1 by corresponding gene

# %%
unique_var = []
var_uni = result['Variation'].values
var_uni_dict = Counter(var_uni)
for key, value in var_uni_dict.items(): 
      if value == 1: # Finding Variations wit single occurence
            unique_var.append(key)
result['Variation'] = result.apply(lambda row : row['Variation'] if row['Variation'] not in unique_var else row['Gene'],axis=1)

# %%
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating_Mutations      1
# 1   1     CBL                   CBL      2
# 2   2     CBL                   CBL      2
# 3   3     CBL                   CBL      3
# 4   4     CBL                   CBL      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %% [markdown]
# <h3>3.1.4. Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4>3.1.4.1. Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
y_true = result['Class'].values
result.Gene      = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')
result.new_variation = result.Variation.str.replace('\s+', '_')

# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)
# split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)

# %% [markdown]
# <p> We split the data into train, test and cross validation data sets, preserving the ratio of class distribution in the original data set  </p>

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cross validation data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 2124
# Number of data points in test data: 665
# Number of data points in cross validation data: 532

# %% [markdown]
# <h4>3.1.4.2. Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = train_df['Class'].value_counts().sortlevel()
test_class_distribution = test_df['Class'].value_counts().sortlevel()
cv_class_distribution = cv_df['Class'].value_counts().sortlevel()

my_colors = 'rgbkymc'
train_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in train data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',train_class_distribution.values[i], '(', np.round((train_class_distribution.values[i]/train_df.shape[0]*100), 3), '%)')

    
print('-'*80)
my_colors = 'rgbkymc'
test_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in test data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-test_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',test_class_distribution.values[i], '(', np.round((test_class_distribution.values[i]/test_df.shape[0]*100), 3), '%)')

print('-'*80)
my_colors = 'rgbkymc'
cv_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in cross validation data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',cv_class_distribution.values[i], '(', np.round((cv_class_distribution.values[i]/cv_df.shape[0]*100), 3), '%)')
# Out:
# Number of data points in class 7 : 609 ( 28.672 %)
# Number of data points in class 4 : 439 ( 20.669 %)
# Number of data points in class 1 : 363 ( 17.09 %)
# Number of data points in class 2 : 289 ( 13.606 %)
# Number of data points in class 6 : 176 ( 8.286 %)
# Number of data points in class 5 : 155 ( 7.298 %)
# Number of data points in class 3 : 57 ( 2.684 %)
# Number of data points in class 9 : 24 ( 1.13 %)
# Number of data points in class 8 : 12 ( 0.565 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 191 ( 28.722 %)
# Number of data points in class 4 : 137 ( 20.602 %)
# Number of data points in class 1 : 114 ( 17.143 %)
# Number of data points in class 2 : 91 ( 13.684 %)
# Number of data points in class 6 : 55 ( 8.271 %)
# Number of data points in class 5 : 48 ( 7.218 %)
# Number of data points in class 3 : 18 ( 2.707 %)
# Number of data points in class 9 : 7 ( 1.053 %)
# Number of data points in class 8 : 4 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 153 ( 28.759 %)
# Number of data points in class 4 : 110 ( 20.677 %)
# Number of data points in class 1 : 91 ( 17.105 %)
# Number of data points in class 2 : 72 ( 13.534 %)
# Number of data points in class 6 : 44 ( 8.271 %)
# Number of data points in class 5 : 39 ( 7.331 %)
# Number of data points in class 3 : 14 ( 2.632 %)
# Number of data points in class 9 : 6 ( 1.128 %)
# Number of data points in class 8 : 3 ( 0.564 %)

# %% [markdown]
# <h2>3.2 Prediction using a 'Random' Model</h2>

# %% [markdown]
# <p style="font-size:16px"> In a 'Random' Model, we generate the NINE class probabilites randomly such that they sum to 1. </p>

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    B =(C/C.sum(axis=0))
    
    labels = [1,2,3,4,5,6,7,8,9]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
test_data_len = test_df.shape[0]
cv_data_len = cv_df.shape[0]

# we create a output array that has exactly same size as the CV data
cv_predicted_y = np.zeros((cv_data_len,9))
for i in range(cv_data_len):
    rand_probs = np.random.rand(1,9)
    cv_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Cross Validation Data using Random Model",log_loss(y_cv,cv_predicted_y, eps=1e-15))


# Test-Set error.
#we create a output array that has exactly same as the test data
test_predicted_y = np.zeros((test_data_len,9))
for i in range(test_data_len):
    rand_probs = np.random.rand(1,9)
    test_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test,test_predicted_y, eps=1e-15))

predicted_y =np.argmax(test_predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y+1)
# Out:
# Log loss on Cross Validation Data using Random Model 2.478963537170697
# Log loss on Test Data using Random Model 2.510817615330925
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h2>3.3 Univariate Analysis</h2>

# %%
# code for response coding with Laplace smoothing.
# alpha : used for laplace smoothing
# feature: ['gene', 'variation']
# df: ['train_df', 'test_df', 'cv_df']
# algorithm
# ----------
# Consider all unique values and the number of occurances of given feature in train data dataframe
# build a vector (1*9) , the first element = (number of times it occured in class1 + 10*alpha / number of time it occurred in total data+90*alpha)
# gv_dict is like a look up table, for every gene it store a (1*9) representation of it
# for a value of feature in df:
# if it is in train data:
# we add the vector that was stored in 'gv_dict' look up table to 'gv_fea'
# if it is not there is train:
# we add [1/9, 1/9, 1/9, 1/9,1/9, 1/9, 1/9, 1/9, 1/9] to 'gv_fea'
# return 'gv_fea'
# ----------------------

# get_gv_fea_dict: Get Gene varaition Feature Dict
def get_gv_fea_dict(alpha, feature, df):
    # value_count: it contains a dict like
    # print(train_df['Gene'].value_counts())
    # output:
    #        {BRCA1      174
    #         TP53       106
    #         EGFR        86
    #         BRCA2       75
    #         PTEN        69
    #         KIT         61
    #         BRAF        60
    #         ERBB2       47
    #         PDGFRA      46
    #         ...}
    # print(train_df['Variation'].value_counts())
    # output:
    # {
    # Truncating_Mutations                     63
    # Deletion                                 43
    # Amplification                            43
    # Fusions                                  22
    # Overexpression                            3
    # E17K                                      3
    # Q61L                                      3
    # S222D                                     2
    # P130S                                     2
    # ...
    # }
    value_count = train_df[feature].value_counts()
    
    # gv_dict : Gene Variation Dict, which contains the probability array for each gene/variation
    gv_dict = dict()
    
    # denominator will contain the number of time that particular feature occured in whole data
    for i, denominator in value_count.items():
        # vec will contain (p(yi==1/Gi) probability of gene/variation belongs to perticular class
        # vec is 9 diamensional vector
        vec = []
        for k in range(1,10):
            # print(train_df.loc[(train_df['Class']==1) & (train_df['Gene']=='BRCA1')])
            #         ID   Gene             Variation  Class  
            # 2470  2470  BRCA1                S1715C      1   
            # 2486  2486  BRCA1                S1841R      1   
            # 2614  2614  BRCA1                   M1R      1   
            # 2432  2432  BRCA1                L1657P      1   
            # 2567  2567  BRCA1                T1685A      1   
            # 2583  2583  BRCA1                E1660G      1   
            # 2634  2634  BRCA1                W1718L      1   
            # cls_cnt.shape[0] will return the number of rows

            cls_cnt = train_df.loc[(train_df['Class']==k) & (train_df[feature]==i)]
            
            # cls_cnt.shape[0](numerator) will contain the number of time that particular feature occured in whole data
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 90*alpha))

        # we are adding the gene/variation to the dict as key and vec as value
        gv_dict[i]=vec
    return gv_dict

# Get Gene variation feature
def get_gv_feature(alpha, feature, df):
    # print(gv_dict)
    #     {'BRCA1': [0.20075757575757575, 0.03787878787878788, 0.068181818181818177, 0.13636363636363635, 0.25, 0.19318181818181818, 0.03787878787878788, 0.03787878787878788, 0.03787878787878788], 
    #      'TP53': [0.32142857142857145, 0.061224489795918366, 0.061224489795918366, 0.27040816326530615, 0.061224489795918366, 0.066326530612244902, 0.051020408163265307, 0.051020408163265307, 0.056122448979591837], 
    #      'EGFR': [0.056818181818181816, 0.21590909090909091, 0.0625, 0.068181818181818177, 0.068181818181818177, 0.0625, 0.34659090909090912, 0.0625, 0.056818181818181816], 
    #      'BRCA2': [0.13333333333333333, 0.060606060606060608, 0.060606060606060608, 0.078787878787878782, 0.1393939393939394, 0.34545454545454546, 0.060606060606060608, 0.060606060606060608, 0.060606060606060608], 
    #      'PTEN': [0.069182389937106917, 0.062893081761006289, 0.069182389937106917, 0.46540880503144655, 0.075471698113207544, 0.062893081761006289, 0.069182389937106917, 0.062893081761006289, 0.062893081761006289], 
    #      'KIT': [0.066225165562913912, 0.25165562913907286, 0.072847682119205295, 0.072847682119205295, 0.066225165562913912, 0.066225165562913912, 0.27152317880794702, 0.066225165562913912, 0.066225165562913912], 
    #      'BRAF': [0.066666666666666666, 0.17999999999999999, 0.073333333333333334, 0.073333333333333334, 0.093333333333333338, 0.080000000000000002, 0.29999999999999999, 0.066666666666666666, 0.066666666666666666],
    #      ...
    #     }
    gv_dict = get_gv_fea_dict(alpha, feature, df)
    # value_count is similar in get_gv_fea_dict
    value_count = train_df[feature].value_counts()
    
    # gv_fea: Gene_variation feature, it will contain the feature for each feature value in the data
    gv_fea = []
    # for every feature values in the given data frame we will check if it is there in the train data then we will add the feature to gv_fea
    # if not we will add [1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9] to gv_fea
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9])
#             gv_fea.append([-1,-1,-1,-1,-1,-1,-1,-1,-1])
    return gv_fea

# %% [markdown]
# when we caculate the probability of a feature belongs to any particular class, we apply laplace smoothing
# <li>(numerator + 10\*alpha) / (denominator + 90\*alpha) </li>

# %% [markdown]
# <h3>3.2.1 Univariate Analysis on Gene Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q1.</b> Gene, What type of feature it is ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Gene is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q2.</b> How many categories are there and How they are distributed?</p>

# %%
unique_genes = train_df['Gene'].value_counts()
print('Number of Unique Genes :', unique_genes.shape[0])
# the top 10 genes that occured most
print(unique_genes.head(10))
# Out:
# Number of Unique Genes : 239
# BRCA1     173
# TP53      103
# EGFR       91
# BRCA2      83
# PTEN       82
# BRAF       63
# KIT        60
# ALK        40
# ERBB2      40
# PIK3CA     40
# Name: Gene, dtype: int64

# %%
print("Ans: There are", unique_genes.shape[0] ,"different categories of genes in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 239 different categories of genes in the train data, and they are distibuted as follows

# %%
s = sum(unique_genes.values);
h = unique_genes.values/s;
plt.plot(h, label="Histrogram of Genes")
plt.xlabel('Index of a Gene')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
plt.plot(c,label='Cumulative distribution of Genes')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <p style="font-size:18px;"> <b>Q3.</b> How to featurize this Gene feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>there are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will choose the appropriate featurization based on the ML model we use.  For this problem of multi-class classification with categorical features, one-hot encoding is better for Logistic regression while response coding is better for Random Forests. </p>

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", train_df))
# test gene feature
test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", test_df))
# cross validation gene feature
cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", cv_df))

# %%
print("train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature:", train_gene_feature_responseCoding.shape)
# Out:
# train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature: (2124, 9)

# %%
# one-hot encoding of Gene feature.[bow]
gene_vectorizer = CountVectorizer()
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature:", train_gene_feature_onehotCoding.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature: (2124, 228)

# %%
# tfidf encoding of gene feature
gene_vectorizer_tf = TfidfVectorizer()
train_gene_feature_onehotCoding2 = gene_vectorizer_tf.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding2 = gene_vectorizer_tf.transform(test_df['Gene'])
cv_gene_feature_onehotCoding2 = gene_vectorizer_tf.transform(cv_df['Gene'])

# %%
print("train_gene_feature_onehotCoding2 is converted feature using tfidf encoding method. The shape of gene feature:", train_gene_feature_onehotCoding2.shape)
# Out:
# train_gene_feature_onehotCoding2 is converted feature using tfidf encoding method. The shape of gene feature: (2124, 228)

# %%
# one-hot encoding of Gene feature.[ngram bow]
gene_vectorizer_ngram = CountVectorizer(ngram_range=(1,2))
train_gene_feature_onehotCoding3 = gene_vectorizer_ngram.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding3 = gene_vectorizer_ngram.transform(test_df['Gene'])
cv_gene_feature_onehotCoding3 = gene_vectorizer_ngram.transform(cv_df['Gene'])

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method(bow ngram). The shape of gene feature:", train_gene_feature_onehotCoding3.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method(bow ngram). The shape of gene feature: (2124, 228)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q4.</b> How good is this gene feature  in predicting y_i?</p>

# %% [markdown]
# There are many ways to estimate how good a feature is, in predicting y_i. One of the good methods is to build a proper ML model using just this feature. In this case, we will build a logistic regression model using only Gene feature (one hot encoded) to predict y_i.

# %%
alpha = [10 ** x for x in range(-5, 1)] # hyperparam for SGD classifier.
cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_gene_feature_onehotCoding, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_gene_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_gene_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_gene_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.3499415007285829
# For values of alpha =  0.0001 The log loss is: 1.1692946513777067
# For values of alpha =  0.001 The log loss is: 1.2018683841715059
# For values of alpha =  0.01 The log loss is: 1.323831769014901
# For values of alpha =  0.1 The log loss is: 1.4364589942653314
# For values of alpha =  1 The log loss is: 1.4754484361189941
# For values of best alpha =  0.0001 The train log loss is: 1.044259670557564
# For values of best alpha =  0.0001 The cross validation log loss is: 1.1692946513777067
# For values of best alpha =  0.0001 The test log loss is: 1.201306019054096

# %% [markdown]
# <p style="font-size:18px;"> <b>Q5.</b> Is the Gene feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it is. Otherwise, the CV and Test errors would be significantly more than train error. </p>

# %%
print("Q6. How many data points in Test and CV datasets are covered by the ", unique_genes.shape[0], " genes in train dataset?")

test_coverage=test_df[test_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]
cv_coverage=cv_df[cv_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]

print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q6. How many data points in Test and CV datasets are covered by the  234  genes in train dataset?
# Ans
# 1. In test data 645 out of 665 : 96.99248120300751
# 2. In cross validation data 516 out of  532 : 96.99248120300751

# %% [markdown]
# <h3>3.2.2 Univariate Analysis on Variation Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q7.</b> Variation, What type of feature is it ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Variation is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q8.</b> How many categories are there?</p>

# %%
unique_variations = train_df['Variation'].value_counts()
print('Number of Unique Variations :', unique_variations.shape[0])
# the top 10 variations that occured most
print(unique_variations.head(10))
# Out:
# Number of Unique Variations : 1934
# Truncating_Mutations    61
# Amplification           53
# Deletion                40
# Fusions                 15
# Overexpression           3
# Q61L                     3
# G12V                     3
# E330K                    2
# Q22K                     2
# G13D                     2
# Name: Variation, dtype: int64

# %%
print("Ans: There are", unique_variations.shape[0] ,"different categories of variations in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 1936 different categories of variations in the train data, and they are distibuted as follows

# %%
s = sum(unique_variations.values);
h = unique_variations.values/s;
plt.plot(h, label="Histrogram of Variations")
plt.xlabel('Index of a Variation')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
print(c)
plt.plot(c,label='Cumulative distribution of Variations')
plt.grid()
plt.legend()
plt.show()
# Out:
# [0.02636535 0.04896422 0.07109228 ... 0.99905838 0.99952919 1.        ]

# %% [markdown]
# <p style="font-size:18px;"> <b>Q9.</b> How to featurize this Variation feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>There are two ways we can featurize this variable
#
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will be using both these methods to featurize the Variation Feature </p>

# %%
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", train_df))
# test gene feature
test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", test_df))
# cross validation gene feature
cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", cv_df))

# %%
print("train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature:", train_variation_feature_responseCoding.shape)
# Out:
# train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature: (2124, 9)

# %%
# one-hot encoding of variation feature.
variation_vectorizer = CountVectorizer()
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# %%
print("train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature:", train_variation_feature_onehotCoding.shape)
# Out:
# train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature: (2124, 227)

# %%
# tfidf one-hot encoding of variation feature.
variation_vectorizer_tf = TfidfVectorizer()
train_variation_feature_onehotCoding2 = variation_vectorizer_tf.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding2 = variation_vectorizer_tf.transform(test_df['Variation'])
cv_variation_feature_onehotCoding2 = variation_vectorizer_tf.transform(cv_df['Variation'])

# %%
print("train_variation_feature_onehotEncoded2 is converted feature using the tfidf encoding method. The shape of Variation feature:", train_variation_feature_onehotCoding2.shape)
# Out:
# train_variation_feature_onehotEncoded2 is converted feature using the tfidf encoding method. The shape of Variation feature: (2124, 227)

# %%
# one-hot encoding of variation feature(BOW) ngram.
variation_vectorizer_ngram = CountVectorizer(ngram_range=(1,2))
train_variation_feature_onehotCoding3 = variation_vectorizer_ngram.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding3 = variation_vectorizer_ngram.transform(test_df['Variation'])
cv_variation_feature_onehotCoding3 = variation_vectorizer_ngram.transform(cv_df['Variation'])

# %% [markdown]
# <p style="font-size:18px;"> <b>Q10.</b> How good is this Variation feature  in predicting y_i?</p>

# %% [markdown]
# Let's build a model just like the earlier!

# %%
alpha = [10 ** x for x in range(-5, 1)]

cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_variation_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_variation_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
    
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_variation_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_variation_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.725144401497222
# For values of alpha =  0.0001 The log loss is: 1.7205366203281491
# For values of alpha =  0.001 The log loss is: 1.7292473960366834
# For values of alpha =  0.01 The log loss is: 1.742820479692335
# For values of alpha =  0.1 The log loss is: 1.7510831956898731
# For values of alpha =  1 The log loss is: 1.751413420923361
# For values of best alpha =  0.0001 The train log loss is: 0.7774858127519523
# For values of best alpha =  0.0001 The cross validation log loss is: 1.7205366203281491
# For values of best alpha =  0.0001 The test log loss is: 1.6863270504595955

# %% [markdown]
# <p style="font-size:18px;"> <b>Q11.</b> Is the Variation feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Not sure! But lets be very sure using the below analysis. </p>

# %%
print("Q12. How many data points are covered by total ", unique_variations.shape[0], " genes in test and cross validation data sets?")
test_coverage=test_df[test_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
cv_coverage=cv_df[cv_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q12. How many data points are covered by total  1936  genes in test and cross validation data sets?
# Ans
# 1. In test data 78 out of 665 : 11.729323308270677
# 2. In cross validation data 50 out of  532 : 9.398496240601503

# %% [markdown]
# <h3>3.2.3 Univariate Analysis on Text Feature</h3>

# %% [markdown]
# 1. How many unique words are present in train data?
# 2. How are word frequencies distributed?
# 3. How to featurize text field?
# 4. Is the text feature useful in predicitng y_i?
# 5. Is the text feature stable across train, test and CV datasets?

# %%
# cls_text is a data frame
# for every row in data fram consider the 'TEXT'
# split the words by space
# make a dict with those words
# increment its count whenever we see that word

def extract_dictionary_paddle(cls_text):
    dictionary = defaultdict(int)
    for index, row in cls_text.iterrows():
        for word in row['TEXT'].split():
            dictionary[word] +=1
    return dictionary

# %%
import math
#https://stackoverflow.com/a/1602964
def get_text_responsecoding(df):
    text_feature_responseCoding = np.zeros((df.shape[0],9))
    for i in range(0,9):
        row_index = 0
        for index, row in df.iterrows():
            sum_prob = 0
            for word in row['TEXT'].split():
                sum_prob += math.log(((dict_list[i].get(word,0)+10 )/(total_dict.get(word,0)+90)))
            text_feature_responseCoding[row_index][i] = math.exp(sum_prob/len(row['TEXT'].split()))
            row_index += 1
    return text_feature_responseCoding

# %%
# bow unigram

# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = CountVectorizer(min_df=3)
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 53908

# %%
dict_list = []
# dict_list =[] contains 9 dictoinaries each corresponds to a class
for i in range(1,10):
    cls_text = train_df[train_df['Class']==i]
    # build a word dict based on the words in that class
    dict_list.append(extract_dictionary_paddle(cls_text))
    # append it to dict_list

# dict_list[i] is build on i'th  class text data
# total_dict is buid on whole training text data
total_dict = extract_dictionary_paddle(train_df)


confuse_array = []
for i in train_text_features:
    ratios = []
    max_val = -1
    for j in range(0,9):
        ratios.append((dict_list[j][i]+10 )/(total_dict[i]+90))
    confuse_array.append(ratios)
confuse_array = np.array(confuse_array)

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(train_df)
test_text_feature_responseCoding  = get_text_responsecoding(test_df)
cv_text_feature_responseCoding  = get_text_responsecoding(cv_df)
# https://stackoverflow.com/a/16202486
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
#https://stackoverflow.com/a/2258273/4084039
sorted_text_fea_dict = dict(sorted(text_fea_dict.items(), key=lambda x: x[1] , reverse=True))
sorted_text_occur = np.array(list(sorted_text_fea_dict.values()))

# %%
# Number of words for a given frequency.
print(Counter(sorted_text_occur))
# Out:
# Counter({3: 5959, 4: 3487, 6: 2861, 5: 2649, 8: 2281, 7: 1997, 9: 1861, 10: 1281, 11: 1230, 12: 1173, 14: 1027, 13: 1001, 18: 883, 15: 795, 16: 791, 20: 651, 19: 606, 24: 546, 17: 513, 22: 511, 21: 471, 28: 413, 26: 410, 25: 394, 27: 367, 23: 347, 30: 333, 29: 301, 31: 295, 49: 291, 46: 280, 33: 277, 32: 269, 36: 268, 42: 248, 35: 227, 40: 215, 34: 211, 38: 209, 48: 208, 37: 202, 44: 196, 39: 195, 43: 188, 45: 181, 52: 177, 55: 169, 41: 166, 50: 162, 53: 155, 54: 151, 47: 149, 56: 141, 51: 134, 63: 133, 57: 127, 60: 120, 72: 117, 62: 116, 64: 114, 59: 111, 61: 110, 66: 106, 65: 100, 84: 99, 76: 94, 58: 91, 78: 90, 80: 89, 70: 89, 67: 89, 92: 85, 73: 85, 75: 84, 68: 84, 83: 82, 77: 82, 95: 77, 105: 75, 71: 71, 90: 70, 81: 70, 74: 70, 87: 69, 79: 69, 100: 68, 86: 66, 69: 65, 126: 64, 85: 63, 91: 62, 88: 62, 82: 62, 106: 61, 98: 61, 111: 60, 108: 60, 99: 59, 97: 57, 94: 57, 93: 56, 104: 55, 112: 54, 113: 53, 89: 52, 120: 51, 130: 50, 107: 48, 102: 48, 96: 47, 134: 46, 136: 45, 117: 45, 114: 45, 138: 44, 116: 42, 101: 42, 132: 41, 109: 41, 103: 41, 148: 39, 135: 39, 110: 39, 123: 38, 115: 38, 154: 37, 147: 37, 142: 37, 129: 37, 127: 37, 125: 37, 144: 36, 143: 36, 124: 36, 140: 35, 133: 35, 119: 35, 118: 35, 170: 34, 137: 34, 131: 33, 152: 31, 162: 30, 160: 30, 149: 30, 145: 30, 128: 30, 121: 30, 171: 29, 165: 29, 161: 29, 153: 29, 122: 29, 198: 28, 167: 28, 163: 28, 146: 28, 173: 27, 166: 27, 150: 27, 141: 27, 180: 26, 172: 26, 169: 26, 216: 25, 182: 25, 158: 25, 139: 25, 225: 24, 208: 24, 177: 24, 174: 24, 168: 24, 164: 24, 155: 24, 239: 23, 233: 23, 224: 23, 206: 23, 202: 23, 181: 23, 156: 23, 242: 22, 205: 22, 190: 22, 189: 22, 184: 22, 178: 22, 176: 22, 151: 22, 247: 21, 227: 21, 215: 21, 267: 20, 232: 20, 230: 20, 226: 20, 200: 20, 183: 20, 179: 20, 159: 20, 157: 20, 264: 19, 260: 19, 240: 19, 221: 19, 220: 19, 219: 19, 199: 19, 192: 19, 188: 19, 186: 19, 341: 18, 236: 18, 234: 18, 223: 18, 214: 18, 213: 18, 211: 18, 210: 18, 197: 18, 193: 18, 187: 18, 175: 18, 306: 17, 302: 17, 298: 17, 265: 17, 228: 17, 209: 17, 204: 17, 203: 17, 196: 17, 322: 16, 278: 16, 252: 16, 249: 16, 248: 16, 246: 16, 217: 16, 195: 16, 325: 15, 295: 15, 290: 15, 270: 15, 262: 15, 253: 15, 245: 15, 201: 15, 194: 15, 324: 14, 289: 14, 261: 14, 256: 14, 254: 14, 244: 14, 191: 14, 337: 13, 312: 13, 307: 13, 291: 13, 269: 13, 250: 13, 238: 13, 231: 13, 229: 13, 433: 12, 397: 12, 349: 12, 329: 12, 328: 12, 300: 12, 296: 12, 285: 12, 279: 12, 273: 12, 268: 12, 263: 12, 255: 12, 251: 12, 241: 12, 235: 12, 218: 12, 212: 12, 185: 12, 434: 11, 410: 11, 385: 11, 378: 11, 344: 11, 330: 11, 316: 11, 304: 11, 299: 11, 283: 11, 274: 11, 272: 11, 271: 11, 243: 11, 237: 11, 568: 10, 565: 10, 473: 10, 469: 10, 461: 10, 446: 10, 412: 10, 406: 10, 392: 10, 355: 10, 352: 10, 347: 10, 333: 10, 332: 10, 323: 10, 317: 10, 313: 10, 311: 10, 293: 10, 288: 10, 287: 10, 284: 10, 282: 10, 281: 10, 276: 10, 258: 10, 257: 10, 222: 10, 207: 10, 460: 9, 432: 9, 404: 9, 396: 9, 384: 9, 376: 9, 372: 9, 358: 9, 351: 9, 343: 9, 342: 9, 335: 9, 331: 9, 321: 9, 319: 9, 318: 9, 301: 9, 294: 9, 292: 9, 275: 9, 720: 8, 627: 8, 608: 8, 558: 8, 510: 8, 502: 8, 499: 8, 476: 8, 459: 8, 458: 8, 448: 8, 447: 8, 441: 8, 430: 8, 429: 8, 402: 8, 399: 8, 393: 8, 367: 8, 365: 8, 362: 8, 361: 8, 357: 8, 356: 8, 354: 8, 336: 8, 277: 8, 266: 8, 783: 7, 735: 7, 712: 7, 663: 7, 636: 7, 578: 7, 553: 7, 544: 7, 532: 7, 530: 7, 528: 7, 512: 7, 507: 7, 498: 7, 494: 7, 484: 7, 479: 7, 470: 7, 455: 7, 454: 7, 443: 7, 438: 7, 431: 7, 422: 7, 414: 7, 408: 7, 395: 7, 394: 7, 391: 7, 388: 7, 386: 7, 383: 7, 382: 7, 380: 7, 379: 7, 377: 7, 373: 7, 370: 7, 366: 7, 363: 7, 350: 7, 340: 7, 338: 7, 334: 7, 327: 7, 320: 7, 308: 7, 305: 7, 303: 7, 297: 7, 286: 7, 280: 7, 259: 7, 1207: 6, 978: 6, 824: 6, 800: 6, 793: 6, 774: 6, 764: 6, 686: 6, 684: 6, 670: 6, 661: 6, 660: 6, 623: 6, 620: 6, 592: 6, 583: 6, 560: 6, 552: 6, 539: 6, 536: 6, 534: 6, 529: 6, 520: 6, 517: 6, 506: 6, 505: 6, 504: 6, 500: 6, 496: 6, 492: 6, 477: 6, 4 ...

# %%
#### Tfidf encoding

text_vectorizer_tf = TfidfVectorizer()
train_text_feature_onehotCoding2 = text_vectorizer_tf.fit(train_df['TEXT'])

train_text_feature_onehotCoding2 = text_vectorizer_tf.transform(train_df['TEXT'])

# getting all the feature names (words)
train_text_features_tf= text_vectorizer_tf.get_feature_names()

test_text_feature_onehotCoding2 = text_vectorizer_tf.transform(test_df['TEXT'])
cv_text_feature_onehotCoding2 = text_vectorizer_tf.transform(cv_df['TEXT'])

print("Total number of unique words in train data :", len(train_text_features_tf))
# Out:
# Total number of unique words in train data : 126133

# %%
### bow ngram model

text_vectorizer3 = CountVectorizer(min_df=3,ngram_range=(1,2))
train_text_feature_onehotCoding3 = text_vectorizer3.fit(train_df['TEXT'])
train_text_feature_onehotCoding3 = text_vectorizer3.transform(train_df['TEXT'])
train_text_features3= text_vectorizer3.get_feature_names()
# don't forget to normalize every feature

train_text_feature_onehotCoding3 = normalize(train_text_feature_onehotCoding3, axis=0)
# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding3 = text_vectorizer3.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding3 = normalize(test_text_feature_onehotCoding3, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding3 = text_vectorizer3.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding3 = normalize(cv_text_feature_onehotCoding3, axis=0)


print("Total number of unique words in train data :", len(train_text_features3))
# Out:
# Total number of unique words in train data : 784422

# %%
# Train a Logistic regression+Calibration model using text features whicha re on-hot encoded
alpha = [10 ** x for x in range(-5, 1)]

cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_text_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_text_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_text_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_text_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.35119143712086
# For values of alpha =  0.0001 The log loss is: 1.3314219828399145
# For values of alpha =  0.001 The log loss is: 1.2353342577436126
# For values of alpha =  0.01 The log loss is: 1.3182508236791188
# For values of alpha =  0.1 The log loss is: 1.49608215981833
# For values of alpha =  1 The log loss is: 1.6627531658079342
# For values of best alpha =  0.001 The train log loss is: 0.7717055622373614
# For values of best alpha =  0.001 The cross validation log loss is: 1.2353342577436126
# For values of best alpha =  0.001 The test log loss is: 1.1492499968117762

# %% [markdown]
# <p style="font-size:18px;"> <b>Q.</b> Is the Text feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it seems like! </p>

# %%
def get_intersec_text(df):
    df_text_vec = CountVectorizer(min_df=3)
    df_text_fea = df_text_vec.fit_transform(df['TEXT'])
    df_text_features = df_text_vec.get_feature_names()

    df_text_fea_counts = df_text_fea.sum(axis=0).A1
    df_text_fea_dict = dict(zip(list(df_text_features),df_text_fea_counts))
    len1 = len(set(df_text_features))
    len2 = len(set(train_text_features) & set(df_text_features))
    return len1,len2

# %%
len1,len2 = get_intersec_text(test_df)
print(np.round((len2/len1)*100, 3), "% of word of test data appeared in train data")
len1,len2 = get_intersec_text(cv_df)
print(np.round((len2/len1)*100, 3), "% of word of Cross Validation appeared in train data")
# Out:
# 97.341 % of word of test data appeared in train data
# 97.365 % of word of Cross Validation appeared in train data

# %% [markdown]
# <h1>4. Machine Learning Models</h1>

# %%
#Data preparation for ML models.

#Misc. functionns for ML models


def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
def report_log_loss(train_x, train_y, test_x, test_y,  clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    sig_clf_probs = sig_clf.predict_proba(test_x)
    return log_loss(test_y, sig_clf_probs, eps=1e-15)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer()
    var_count_vec = CountVectorizer()
    text_count_vec = CountVectorizer(min_df=3)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
####code for stacking unigram

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))


#### code for stacking response vectors

train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (2124, 54363)
# (number of data points * number of features) in test data =  (665, 54363)
# (number of data points * number of features) in cross validation data = (532, 54363)

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (2124, 27)
# (number of data points * number of features) in test data =  (665, 27)
# (number of data points * number of features) in cross validation data = (532, 27)

# %%
## code for stacking tfidf vectors

train_gene_var_onehotCoding2 = hstack((train_gene_feature_onehotCoding2,train_variation_feature_onehotCoding2))
test_gene_var_onehotCoding2 = hstack((test_gene_feature_onehotCoding2,test_variation_feature_onehotCoding2))
cv_gene_var_onehotCoding2 = hstack((cv_gene_feature_onehotCoding2,cv_variation_feature_onehotCoding2))


train_x_onehotCoding2 = hstack((train_gene_var_onehotCoding2, train_text_feature_onehotCoding2))
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding2 = hstack((test_gene_var_onehotCoding2, test_text_feature_onehotCoding2))
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding2 = hstack((cv_gene_var_onehotCoding2, cv_text_feature_onehotCoding2)).tocsr()
cv_y = np.array(list(cv_df['Class']))

# %% [markdown]
# #### We will perform additional feature engineering on Tfidf vectors as below

# %%
#As an addittional feature engineering we will take squatre root of tfidf vectors
train_x_onehotCoding2 = np.sqrt(train_x_onehotCoding2).tocsr()
test_x_onehotCoding2 = np.sqrt(test_x_onehotCoding2).tocsr()
cv_x_onehotCoding2 = np.sqrt(cv_x_onehotCoding2).tocsr()

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding2.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding2.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding2.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (2124, 126588)
# (number of data points * number of features) in test data =  (665, 126588)
# (number of data points * number of features) in cross validation data = (532, 126588)

# %%
### code for ngram
train_gene_var_onehotCoding3 = hstack((train_gene_feature_onehotCoding3,train_variation_feature_onehotCoding3))
test_gene_var_onehotCoding3 = hstack((test_gene_feature_onehotCoding3,test_variation_feature_onehotCoding3))
cv_gene_var_onehotCoding3 = hstack((cv_gene_feature_onehotCoding3,cv_variation_feature_onehotCoding3))

train_x_onehotCoding3 = hstack((train_gene_var_onehotCoding3, train_text_feature_onehotCoding3)).tocsr()

test_x_onehotCoding3 = hstack((test_gene_var_onehotCoding3, test_text_feature_onehotCoding3)).tocsr()

cv_x_onehotCoding3 = hstack((cv_gene_var_onehotCoding3, cv_text_feature_onehotCoding3)).tocsr()

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# ### Naive Bayes using BOW

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.307615393536416
# for alpha = 0.0001
# Log Loss : 1.2916311693962663
# for alpha = 0.001
# Log Loss : 1.275751147305724
# for alpha = 0.1
# Log Loss : 1.255054882925893
# for alpha = 1
# Log Loss : 1.309271300302503
# for alpha = 10
# Log Loss : 1.4505326709024926
# for alpha = 100
# Log Loss : 1.3892951082485376
# for alpha = 1000
# Log Loss : 1.3440054348421082
# For values of best alpha =  0.1 The train log loss is: 0.9004192869574864
# For values of best alpha =  0.1 The cross validation log loss is: 1.255054882925893
# For values of best alpha =  0.1 The test log loss is: 1.2562388205102333

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding.toarray()))
# Out:
# Log Loss : 1.255054882925893
# Number of missclassified point : 0.39285714285714285
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.081  0.0753 0.0124 0.091  0.0363 0.0331 0.6639 0.0041 0.003 ]]
# Actual Class : 7
# --------------------------------------------------
# 29 Text feature [kinase] present in test data point [True]
# 30 Text feature [downstream] present in test data point [True]
# 31 Text feature [presence] present in test data point [True]
# 32 Text feature [independent] present in test data point [True]
# 33 Text feature [activating] present in test data point [True]
# 34 Text feature [inhibitor] present in test data point [True]
# 35 Text feature [well] present in test data point [True]
# 38 Text feature [recently] present in test data point [True]
# 39 Text feature [also] present in test data point [True]
# 40 Text feature [expressing] present in test data point [True]
# 41 Text feature [cells] present in test data point [True]
# 42 Text feature [however] present in test data point [True]
# 43 Text feature [previously] present in test data point [True]
# 44 Text feature [contrast] present in test data point [True]
# 45 Text feature [growth] present in test data point [True]
# 46 Text feature [activation] present in test data point [True]
# 47 Text feature [potential] present in test data point [True]
# 48 Text feature [showed] present in test data point [True]
# 49 Text feature [cell] present in test data point [True]
# 50 Text feature [shown] present in test data point [True]
# 51 Text feature [treated] present in test data point [True]
# 53 Text feature [similar] present in test data point [True]
# 54 Text feature [factor] present in test data point [True]
# 55 Text feature [higher] present in test data point [True]
# 56 Text feature [suggest] present in test data point [True]
# 58 Text feature [mutations] present in test data point [True]
# 59 Text feature [10] present in test data point [True]
# 60 Text feature [addition] present in test data point [True]
# 61 Text feature [12] present in test data point [True]
# 62 Text feature [obtained] present in test data point [True]
# 64 Text feature [may] present in test data point [True]
# 65 Text feature [studies] present in test data point [True]
# 66 Text feature [described] present in test data point [True]
# 67 Text feature [inhibitors] present in test data point [True]
# 68 Text feature [found] present in test data point [True]
# 69 Text feature [1a] present in test data point [True]
# 71 Text feature [report] present in test data point [True]
# 72 Text feature [observed] present in test data point [True]
# 73 Text feature [reported] present in test data point [True]
# 74 Text feature [interestingly] present in test data point [True]
# 82 Text feature [total] present in test data point [True]
# 83 Text feature [sensitive] present in test data point [True]
# 84 Text feature [using] present in test data point [True]
# 85 Text feature [including] present in test data point [True]
# 86 Text feature [confirm] present in test data point [True]
# 88 Text feature [three] present in test data point [True]
# 89 Text feature [concentrations] present in test data point [True]
# 90 Text feature [approximately] present in test data point [True]
# 91 Text feature [confirmed] present in test data point [True]
# 92 Text feature [show] present in test data point [True]
# 93 Text feature [proliferation] present in test data point [True]
# 94 Text feature [fig] present in test data point [True]
# 96 Text feature [whereas] present in test data point [True]
# 97 Text feature [results] present in test data point [True]
# 98 Text feature [various] present in test data point [True]
# Out of the top  100  features  55 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 5
# Predicted Class Probabilities: [[0.1193 0.1116 0.1763 0.1346 0.2222 0.0492 0.1763 0.0061 0.0044]]
# Actual Class : 7
# --------------------------------------------------
# 9 Text feature [assays] present in test data point [True]
# 10 Text feature [variants] present in test data point [True]
# 11 Text feature [functional] present in test data point [True]
# 38 Text feature [predict] present in test data point [True]
# Out of the top  100  features  4 are present in query point

# %% [markdown]
# <h2>4.2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>4.2.1. Hyper parameter tuning</h3>

# %%
alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_responseCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_responseCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 5
# Log Loss : 1.333662707343848
# for alpha = 11
# Log Loss : 1.3090468867381335
# for alpha = 15
# Log Loss : 1.295451782830171
# for alpha = 21
# Log Loss : 1.2845944924604813
# for alpha = 31
# Log Loss : 1.283626650515353
# for alpha = 41
# Log Loss : 1.3032433668884456
# for alpha = 51
# Log Loss : 1.3334474953622857
# for alpha = 99
# Log Loss : 1.3248534957728655
# For values of best alpha =  31 The train log loss is: 1.1202665862481622
# For values of best alpha =  31 The cross validation log loss is: 1.283626650515353
# For values of best alpha =  31 The test log loss is: 1.2919793642759905

# %% [markdown]
# <h3>4.2.2. Testing the model with best hyper paramters</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/n-with-a-toy-example-1/
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y, cv_x_responseCoding, cv_y, clf)
# Out:
# Log loss : 1.283626650515353
# Number of mis-classified points : 0.46616541353383456
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.2.3.Sample Query point -1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_responseCoding[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 7
# The  31  nearest neighbours of the test points belongs to classes [7 7 2 7 7 7 7 7 2 2 2 2 5 7 7 7 3 7 7 7 7 7 7 2 7 2 7 2 2 7 7]
# Fequency of nearest points : Counter({7: 20, 2: 9, 5: 1, 3: 1})

# %% [markdown]
# <h3>4.2.4. Sample Query Point-2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 10

predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 6
# Actual Class : 5
# the k value for knn is 31 and the nearest neighbours of the test points belongs to classes [6 1 6 4 4 1 1 4 1 4 1 5 1 4 6 1 6 8 4 8 1 6 1 1 6 6 5 4 1 6 1]
# Fequency of nearest points : Counter({1: 12, 6: 8, 4: 7, 5: 2, 8: 2})

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.3742258043336568
# for alpha = 1e-05
# Log Loss : 1.3783289653477997
# for alpha = 0.0001
# Log Loss : 1.2952936252928515
# for alpha = 0.001
# Log Loss : 1.0829339597475736
# for alpha = 0.01
# Log Loss : 1.1497830569976883
# for alpha = 0.1
# Log Loss : 1.4552227738512282
# for alpha = 1
# Log Loss : 1.70535919109663
# for alpha = 10
# Log Loss : 1.736289242469709
# for alpha = 100
# Log Loss : 1.739540654560841
# For values of best alpha =  0.001 The train log loss is: 0.6561783547896695
# For values of best alpha =  0.001 The cross validation log loss is: 1.0829339597475736
# For values of best alpha =  0.001 The test log loss is: 1.0811992480569574

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0829339597475736
# Number of mis-classified points : 0.36654135338345867
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0236 0.055  0.0064 0.0138 0.0205 0.0115 0.8593 0.0055 0.0045]]
# Actual Class : 7
# --------------------------------------------------
# 37 Text feature [constitutive] present in test data point [True]
# 74 Text feature [downstream] present in test data point [True]
# 123 Text feature [lasota] present in test data point [True]
# 154 Text feature [rac] present in test data point [True]
# 199 Text feature [tk] present in test data point [True]
# 228 Text feature [inhibited] present in test data point [True]
# 260 Text feature [independence] present in test data point [True]
# 270 Text feature [expressing] present in test data point [True]
# 291 Text feature [extracellular] present in test data point [True]
# 309 Text feature [tyr] present in test data point [True]
# 368 Text feature [oncoproteins] present in test data point [True]
# 380 Text feature [pharma] present in test data point [True]
# Out of the top  500  features  12 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 5
# Predicted Class Probabilities: [[0.0186 0.0358 0.2633 0.0137 0.3255 0.0093 0.3214 0.0071 0.0052]]
# Actual Class : 7
# --------------------------------------------------
# 95 Text feature [leverage] present in test data point [True]
# 224 Text feature [and4] present in test data point [True]
# 354 Text feature [t1151m] present in test data point [True]
# 362 Text feature [computationally] present in test data point [True]
# 402 Text feature [fell] present in test data point [True]
# 405 Text feature [and44] present in test data point [True]
# 431 Text feature [suggestions] present in test data point [True]
# Out of the top  500  features  7 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.3240914629845115
# for alpha = 1e-05
# Log Loss : 1.3267075362338183
# for alpha = 0.0001
# Log Loss : 1.3011963659530565
# for alpha = 0.001
# Log Loss : 1.1550896394132881
# for alpha = 0.01
# Log Loss : 1.2172286866411637
# for alpha = 0.1
# Log Loss : 1.3787378225174585
# for alpha = 1
# Log Loss : 1.5702688455095073
# For values of best alpha =  0.001 The train log loss is: 0.6648025088563998
# For values of best alpha =  0.001 The cross validation log loss is: 1.1550896394132881
# For values of best alpha =  0.001 The test log loss is: 1.0932054779709366

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.1550896394132881
# Number of mis-classified points : 0.36466165413533835
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0284 0.058  0.0065 0.0155 0.0216 0.0111 0.8527 0.0053 0.0009]]
# Actual Class : 7
# --------------------------------------------------
# 79 Text feature [constitutive] present in test data point [True]
# 105 Text feature [downstream] present in test data point [True]
# 160 Text feature [rac] present in test data point [True]
# 201 Text feature [independence] present in test data point [True]
# 212 Text feature [expressing] present in test data point [True]
# 216 Text feature [lasota] present in test data point [True]
# 244 Text feature [inhibited] present in test data point [True]
# 297 Text feature [extracellular] present in test data point [True]
# 419 Text feature [tk] present in test data point [True]
# 426 Text feature [oncoproteins] present in test data point [True]
# 475 Text feature [pharma] present in test data point [True]
# 480 Text feature [tyr] present in test data point [True]
# 484 Text feature [driven] present in test data point [True]
# 485 Text feature [activating] present in test data point [True]
# Out of the top  500  features  14 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[2.160e-02 3.350e-02 1.847e-01 1.690e-02 3.241e-01 8.400e-03 4.030e-01
#   7.200e-03 4.000e-04]]
# Actual Class : 7
# --------------------------------------------------
# 62 Text feature [constitutively] present in test data point [True]
# 71 Text feature [3t3] present in test data point [True]
# 79 Text feature [constitutive] present in test data point [True]
# 93 Text feature [transforming] present in test data point [True]
# 105 Text feature [downstream] present in test data point [True]
# 115 Text feature [oncogene] present in test data point [True]
# 129 Text feature [manageable] present in test data point [True]
# 138 Text feature [transformation] present in test data point [True]
# 163 Text feature [cancers11] present in test data point [True]
# 166 Text feature [deeper] present in test data point [True]
# 175 Text feature [transform] present in test data point [True]
# 195 Text feature [oncogenes] present in test data point [True]
# 201 Text feature [independence] present in test data point [True]
# 231 Text feature [activated] present in test data point [True]
# 234 Text feature [cells6] present in test data point [True]
# 253 Text feature [autophosphorylation] present in test data point [True]
# 297 Text feature [extracellular] present in test data point [True]
# 305 Text feature [billions] present in test data point [True]
# 347 Text feature [studies4] present in test data point [True]
# 361 Text feature [remain] present in test data point [True]
# 368 Text feature [dramatic] present in test data point [True]
# 379 Text feature [alk14] present in test data point [True]
# 390 Text feature [designing] present in test data point [True]
# 425 Text feature [experienced] present in test data point [True]
# 443 Text feature [fashioned] present in test data point [True]
# 444 Text feature [season] present in test data point [True]
# 445 Text feature [prognostics] present in test data point [True]
# 446 Text feature [trump] present in test data point [True]
# 447 Text feature [ergistically] present in test data point [True]
# 448 Text feature [tricks] present in test data point [True]
# 449 Text feature [effectively12] present in test data point [True]
# 450 Text feature [audrey] present in test data point [True]
# 451 Text feature [outcome8] present in test data point [True]
# 452 Text feature [myoblastic] present in test data point [True]
# 453 Text feature [emerges13] present in test data point [True]
# 454 Text feature [activity10] present in test data point [True]
# 455 Text feature [difference8] present in test data point [True]
# 456 Text feature [paraphrase] present in test data point [True]
# 484 Text feature [driven] present in test data point [True]
# 485 Text feature [activating] present in test data point [True]
# Out of the top  500  features  40 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.4.1. Hyper paramter tuning</h3>

# %%
alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.3664621031803421
# for C = 0.0001
# Log Loss : 1.3433840082942796
# for C = 0.001
# Log Loss : 1.2489162560208598
# for C = 0.01
# Log Loss : 1.1426918558214054
# for C = 0.1
# Log Loss : 1.3421054180739758
# for C = 1
# Log Loss : 1.731526497340441
# for C = 10
# Log Loss : 1.7402951988246542
# for C = 100
# Log Loss : 1.7401763981735912
# For values of best alpha =  0.01 The train log loss is: 0.7836433128298517
# For values of best alpha =  0.01 The cross validation log loss is: 1.1426918558214054
# For values of best alpha =  0.01 The test log loss is: 1.1548785442375766

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.1426918558214054
# Number of mis-classified points : 0.36466165413533835
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
# test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0502 0.0441 0.0057 0.0421 0.0329 0.0172 0.7997 0.0046 0.0035]]
# Actual Class : 7
# --------------------------------------------------
# 68 Text feature [constitutive] present in test data point [True]
# 69 Text feature [expressing] present in test data point [True]
# 133 Text feature [downstream] present in test data point [True]
# 143 Text feature [independence] present in test data point [True]
# 163 Text feature [rac] present in test data point [True]
# 204 Text feature [cdnas] present in test data point [True]
# 219 Text feature [pharma] present in test data point [True]
# 224 Text feature [tyrosyl] present in test data point [True]
# 263 Text feature [concentrations] present in test data point [True]
# 345 Text feature [tyr] present in test data point [True]
# 361 Text feature [extracellular] present in test data point [True]
# 369 Text feature [oncoproteins] present in test data point [True]
# 384 Text feature [activating] present in test data point [True]
# 386 Text feature [inhibitor] present in test data point [True]
# 476 Text feature [inhibited] present in test data point [True]
# 484 Text feature [stably] present in test data point [True]
# Out of the top  500  features  16 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 7
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0979 0.0881 0.0148 0.092  0.0349 0.0355 0.6262 0.0051 0.0056]]
# Actual Class : 2
# --------------------------------------------------
# 66 Text feature [cysteine] present in test data point [True]
# 68 Text feature [constitutive] present in test data point [True]
# 74 Text feature [fgf1] present in test data point [True]
# 133 Text feature [downstream] present in test data point [True]
# 156 Text feature [pfeiffer] present in test data point [True]
# 197 Text feature [crouzon] present in test data point [True]
# 202 Text feature [craniosynostosis] present in test data point [True]
# 242 Text feature [activated] present in test data point [True]
# 246 Text feature [g370c] present in test data point [True]
# 293 Text feature [ornitz] present in test data point [True]
# 294 Text feature [fgf10] present in test data point [True]
# 361 Text feature [extracellular] present in test data point [True]
# 373 Text feature [mapk] present in test data point [True]
# 384 Text feature [activating] present in test data point [True]
# 386 Text feature [inhibitor] present in test data point [True]
# 392 Text feature [thanatophoric] present in test data point [True]
# 430 Text feature [gyrata] present in test data point [True]
# Out of the top  500  features  17 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With One hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------


alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.2683293214441969
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.1926068129337573
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.2596392134383516
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.1945585320969703
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.2571177155085185
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.183902002604779
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.2496517922555281
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.1815528350770355
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.2448927807778485
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.183059517080934
# For values of best estimator =  1000 The train log loss is: 0.7365138623782628
# For values of best estimator =  1000 The cross validation log loss is: 1.1815528350770355
# For values of best estimator =  1000 The test log loss is: 1.159297935718912

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.1815528350770355
# Number of mis-classified points : 0.3890977443609023
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0411 0.163  0.0185 0.0318 0.0387 0.0283 0.6689 0.0049 0.0048]]
# Actuall Class : 7
# --------------------------------------------------
# 0 Text feature [tyrosine] present in test data point [True]
# 1 Text feature [kinase] present in test data point [True]
# 2 Text feature [activating] present in test data point [True]
# 3 Text feature [inhibitors] present in test data point [True]
# 5 Text feature [phosphorylation] present in test data point [True]
# 6 Text feature [activation] present in test data point [True]
# 9 Text feature [oncogenic] present in test data point [True]
# 11 Text feature [constitutive] present in test data point [True]
# 14 Text feature [signaling] present in test data point [True]
# 15 Text feature [receptor] present in test data point [True]
# 16 Text feature [kinases] present in test data point [True]
# 18 Text feature [cells] present in test data point [True]
# 22 Text feature [ic50] present in test data point [True]
# 23 Text feature [inhibitor] present in test data point [True]
# 24 Text feature [treatment] present in test data point [True]
# 25 Text feature [growth] present in test data point [True]
# 34 Text feature [resistant] present in test data point [True]
# 35 Text feature [patients] present in test data point [True]
# 39 Text feature [therapy] present in test data point [True]
# 43 Text feature [expressing] present in test data point [True]
# 44 Text feature [downstream] present in test data point [True]
# 46 Text feature [protein] present in test data point [True]
# 47 Text feature [therapeutic] present in test data point [True]
# 48 Text feature [trials] present in test data point [True]
# 49 Text feature [drug] present in test data point [True]
# 61 Text feature [proliferation] present in test data point [True]
# 62 Text feature [sensitive] present in test data point [True]
# 64 Text feature [respond] present in test data point [True]
# 66 Text feature [treated] present in test data point [True]
# 68 Text feature [resistance] present in test data point [True]
# 70 Text feature [clinical] present in test data point [True]
# 73 Text feature [response] present in test data point [True]
# 74 Text feature [advanced] present in test data point [True]
# 75 Text feature [expression] present in test data point [True]
# 76 Text feature [cell] present in test data point [True]
# 84 Text feature [dna] present in test data point [True]
# 85 Text feature [type] present in test data point [True]
# 86 Text feature [f3] present in test data point [True]
# 89 Text feature [ba] present in test data point [True]
# 93 Text feature [proteins] present in test data point [True]
# 95 Text feature [gene] present in test data point [True]
# 98 Text feature [lines] present in test data point [True]
# Out of the top  100  features  42 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.1105 0.1079 0.0253 0.1423 0.059  0.053  0.4881 0.0071 0.0068]]
# Actual Class : 5
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [activating] present in test data point [True]
# 2 Text feature [activation] present in test data point [True]
# 3 Text feature [inhibitors] present in test data point [True]
# 7 Text feature [constitutive] present in test data point [True]
# 8 Text feature [phosphorylation] present in test data point [True]
# 10 Text feature [signaling] present in test data point [True]
# 11 Text feature [akt] present in test data point [True]
# 15 Text feature [function] present in test data point [True]
# 18 Text feature [downstream] present in test data point [True]
# 19 Text feature [oncogenic] present in test data point [True]
# 20 Text feature [cells] present in test data point [True]
# 21 Text feature [loss] present in test data point [True]
# 22 Text feature [growth] present in test data point [True]
# 24 Text feature [functional] present in test data point [True]
# 25 Text feature [constitutively] present in test data point [True]
# 29 Text feature [inhibition] present in test data point [True]
# 31 Text feature [cell] present in test data point [True]
# 33 Text feature [stability] present in test data point [True]
# 34 Text feature [activate] present in test data point [True]
# 40 Text feature [lines] present in test data point [True]
# 45 Text feature [proliferation] present in test data point [True]
# 47 Text feature [protein] present in test data point [True]
# 49 Text feature [clinical] present in test data point [True]
# 57 Text feature [oncogene] present in test data point [True]
# 64 Text feature [proteins] present in test data point [True]
# 65 Text feature [transforming] present in test data point [True]
# 72 Text feature [sensitivity] present in test data point [True]
# 81 Text feature [neutral] present in test data point [True]
# 86 Text feature [transformation] present in test data point [True]
# 90 Text feature [ras] present in test data point [True]
# 92 Text feature [enhanced] present in test data point [True]
# 99 Text feature [sensitive] present in test data point [True]
# Out of the top  100  features  33 are present in query point

# %% [markdown]
# <h3>4.5.3. Hyper paramter tuning (With Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10,50,100,200,500,1000]
max_depth = [2,3,5,10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_responseCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_responseCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 
'''
fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/4)],max_depth[int(i%4)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 10 and max depth =  2
# Log Loss : 1.2087549600303675
# for n_estimators = 10 and max depth =  3
# Log Loss : 1.1145221894639967
# for n_estimators = 10 and max depth =  5
# Log Loss : 1.0573477938249396
# for n_estimators = 10 and max depth =  10
# Log Loss : 1.0871988486133513
# for n_estimators = 50 and max depth =  2
# Log Loss : 1.1356052142451611
# for n_estimators = 50 and max depth =  3
# Log Loss : 1.0804343926825333
# for n_estimators = 50 and max depth =  5
# Log Loss : 1.035809777773705
# for n_estimators = 50 and max depth =  10
# Log Loss : 1.060810228270442
# for n_estimators = 100 and max depth =  2
# Log Loss : 1.1415167601875345
# for n_estimators = 100 and max depth =  3
# Log Loss : 1.0735032622254481
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.0385092688593283
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.0536688605391948
# for n_estimators = 200 and max depth =  2
# Log Loss : 1.1302935998001695
# for n_estimators = 200 and max depth =  3
# Log Loss : 1.0651096021453346
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.035919155498336
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.0504325997749406
# for n_estimators = 500 and max depth =  2
# Log Loss : 1.1254835875036844
# for n_estimators = 500 and max depth =  3
# Log Loss : 1.0664282083542669
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.034594938640951
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.0480105998030143
# for n_estimators = 1000 and max depth =  2
# Log Loss : 1.1248269198465704
# for n_estimators = 1000 and max depth =  3
# Log Loss : 1.0644717038222644
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.0351195972954044
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.0507036431511023
# For values of best alpha =  500 The train log loss is: 0.6928981155239216
# For values of best alpha =  500 The cross validation log loss is: 1.034594938640951
# For values of best alpha =  500 The test log loss is: 1.0740551410134307

# %% [markdown]
# <h3>4.5.4. Testing model with best hyper parameters (Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(max_depth=max_depth[int(best_alpha%4)], n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_features='auto',random_state=42)
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y,cv_x_responseCoding,cv_y, clf)
# Out:
# Log loss : 1.034594938640951
# Number of mis-classified points : 0.37218045112781956
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.5. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.5.1. Correctly Classified point</h4>

# %%
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)


test_point_index = 6
no_feature = 27
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.1542 0.0144 0.0196 0.3203 0.2716 0.0567 0.0152 0.0156 0.1323]]
# Actual Class : 4
# --------------------------------------------------
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature

# %% [markdown]
# <h4>4.5.5.2. Incorrectly Classified point</h4>

# %%
test_point_index = 3
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0385 0.3338 0.0171 0.0388 0.0465 0.036  0.475  0.0084 0.0059]]
# Actual Class : 2
# --------------------------------------------------
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------

#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 1.07
# Support vector machines : Log Loss: 1.73
# Naive Bayes : Log Loss: 1.28
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.179
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 2.044
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.549
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.160
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.194
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.369

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.7212942495157146
# Log loss (CV) on the stacking classifier : 1.160288036588035
# Log loss (test) on the stacking classifier : 1.1102969204806132
# Number of missclassified point : 0.36390977443609024
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the VotingClassifier : 0.9394316533004986
# Log loss (CV) on the VotingClassifier : 1.195316417729366
# Log loss (test) on the VotingClassifier : 1.2004999111990593
# Number of missclassified point : 0.35789473684210527
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h1>5. Applying ML Model with TFIDF vectorizer</h1>

# %% [markdown]
# ## Naive Bayes on TFIDF

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = TfidfVectorizer()
    var_count_vec = TfidfVectorizer()
    text_count_vec = TfidfVectorizer()
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %%
## Hyper parameter tuning

train_x_onehotCoding = train_x_onehotCoding2
test_x_onehotCoding = test_x_onehotCoding2
cv_x_onehotCoding = cv_x_onehotCoding2

alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.2269203890031377
# for alpha = 0.0001
# Log Loss : 1.2158220160606816
# for alpha = 0.001
# Log Loss : 1.208093674558761
# for alpha = 0.1
# Log Loss : 1.303884161065255
# for alpha = 1
# Log Loss : 1.6557806914320123
# for alpha = 10
# Log Loss : 1.7462019548139702
# for alpha = 100
# Log Loss : 1.6218775426254282
# for alpha = 1000
# Log Loss : 1.5233965448814741
# For values of best alpha =  0.001 The train log loss is: 0.8579168852231372
# For values of best alpha =  0.001 The cross validation log loss is: 1.208093674558761
# For values of best alpha =  0.001 The test log loss is: 1.2034568130729568

# %%
# fitting best model

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding.toarray()))
# Out:
# Log Loss : 1.208093674558761
# Number of missclassified point : 0.35902255639097747
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
## Feature importance of correctly classified points
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0792 0.0752 0.0128 0.0911 0.0406 0.0368 0.6562 0.0048 0.0033]]
# Actual Class : 7
# --------------------------------------------------
# 0 Text feature [mutations] present in test data point [True]
# 1 Text feature [cells] present in test data point [True]
# 2 Text feature [cell] present in test data point [True]
# 3 Text feature [kinase] present in test data point [True]
# 4 Text feature [mutation] present in test data point [True]
# 5 Text feature [fig] present in test data point [True]
# 6 Text feature [figure] present in test data point [True]
# 7 Text feature [patients] present in test data point [True]
# 8 Text feature [cancer] present in test data point [True]
# 9 Text feature [mutant] present in test data point [True]
# 10 Text feature [activation] present in test data point [True]
# 11 Text feature [activity] present in test data point [True]
# 12 Text feature [domain] present in test data point [True]
# 13 Text feature [expression] present in test data point [True]
# 14 Text feature [also] present in test data point [True]
# 15 Text feature [et] present in test data point [True]
# 16 Text feature [al] present in test data point [True]
# 17 Text feature [tumor] present in test data point [True]
# 18 Text feature [using] present in test data point [True]
# 19 Text feature [protein] present in test data point [True]
# 20 Text feature [mutants] present in test data point [True]
# 21 Text feature [10] present in test data point [True]
# 22 Text feature [tumors] present in test data point [True]
# 23 Text feature [type] present in test data point [True]
# 24 Text feature [signaling] present in test data point [True]
# 25 Text feature [growth] present in test data point [True]
# 27 Text feature [data] present in test data point [True]
# 28 Text feature [phosphorylation] present in test data point [True]
# 30 Text feature [gene] present in test data point [True]
# 31 Text feature [two] present in test data point [True]
# 32 Text feature [may] present in test data point [True]
# 33 Text feature [table] present in test data point [True]
# 34 Text feature [treatment] present in test data point [True]
# 35 Text feature [shown] present in test data point [True]
# 36 Text feature [results] present in test data point [True]
# 37 Text feature [identified] present in test data point [True]
# 38 Text feature [lines] present in test data point [True]
# 39 Text feature [found] present in test data point [True]
# 40 Text feature [receptor] present in test data point [True]
# 41 Text feature [wild] present in test data point [True]
# 42 Text feature [expressing] present in test data point [True]
# 43 Text feature [inhibitors] present in test data point [True]
# 44 Text feature [tyrosine] present in test data point [True]
# 45 Text feature [clinical] present in test data point [True]
# 46 Text feature [binding] present in test data point [True]
# 47 Text feature [study] present in test data point [True]
# 48 Text feature [one] present in test data point [True]
# 49 Text feature [inhibitor] present in test data point [True]
# 50 Text feature [exon] present in test data point [True]
# 51 Text feature [observed] present in test data point [True]
# 52 Text feature [associated] present in test data point [True]
# 53 Text feature [human] present in test data point [True]
# 54 Text feature [dna] present in test data point [True]
# 55 Text feature [showed] present in test data point [True]
# 56 Text feature [used] present in test data point [True]
# 57 Text feature [12] present in test data point [True]
# 58 Text feature [activating] present in test data point [True]
# 60 Text feature [well] present in test data point [True]
# 62 Text feature [kit] present in test data point [True]
# 63 Text feature [previously] present in test data point [True]
# 66 Text feature [however] present in test data point [True]
# 67 Text feature [resistance] present in test data point [True]
# 68 Text feature [20] present in test data point [True]
# 69 Text feature [reported] present in test data point [True]
# 70 Text feature [studies] present in test data point [True]
# 71 Text feature [three] present in test data point [True]
# 75 Text feature [genes] present in test data point [True]
# 77 Text feature [different] present in test data point [True]
# 78 Text feature [patient] present in test data point [True]
# 79 Text feature [levels] present in test data point [True]
# 80 Text feature [response] present in test data point [True]
# 82 Text feature [described] present in test data point [True]
# 84 Text feature [proliferation] present in test data point [True]
# 85 Text feature [anti] present in test data point [True]
# 86 Text feature [survival] present in test data point [True]
# 87 Text feature [15] present in test data point [True]
# 88 Text feature [14] present in test data point [True]
# 90 Text feature [oncogenic] present in test data point [True]
# 91 Text feature [specific] present in test data point [True]
# 92 Text feature [11] present in test data point [True]
# 93 Text feature [cases] present in test data point [True]
# 94 Text feature [sequencing] present in test data point [True]
# 95 Text feature [samples] present in test data point [True]
# 96 Text feature [proteins] present in test data point [True]
# 97 Text feature [including] present in test data point [True]
# 98 Text feature [presence] present in test data point [True]
# 99 Text feature [similar] present in test data point [True]
# Out of the top  100  features  87 are present in query point

# %%
## Feature importance of incorrectly classified points
test_point_index = 19
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0835 0.2466 0.0136 0.0962 0.0425 0.0385 0.4704 0.0051 0.0036]]
# Actual Class : 7
# --------------------------------------------------
# 0 Text feature [mutations] present in test data point [True]
# 1 Text feature [cells] present in test data point [True]
# 2 Text feature [cell] present in test data point [True]
# 3 Text feature [kinase] present in test data point [True]
# 4 Text feature [mutation] present in test data point [True]
# 5 Text feature [fig] present in test data point [True]
# 6 Text feature [figure] present in test data point [True]
# 7 Text feature [patients] present in test data point [True]
# 8 Text feature [cancer] present in test data point [True]
# 9 Text feature [mutant] present in test data point [True]
# 10 Text feature [activation] present in test data point [True]
# 11 Text feature [activity] present in test data point [True]
# 12 Text feature [domain] present in test data point [True]
# 13 Text feature [expression] present in test data point [True]
# 14 Text feature [also] present in test data point [True]
# 15 Text feature [et] present in test data point [True]
# 16 Text feature [al] present in test data point [True]
# 17 Text feature [tumor] present in test data point [True]
# 18 Text feature [using] present in test data point [True]
# 19 Text feature [protein] present in test data point [True]
# 20 Text feature [mutants] present in test data point [True]
# 21 Text feature [10] present in test data point [True]
# 22 Text feature [tumors] present in test data point [True]
# 23 Text feature [type] present in test data point [True]
# 24 Text feature [signaling] present in test data point [True]
# 25 Text feature [growth] present in test data point [True]
# 26 Text feature [egfr] present in test data point [True]
# 27 Text feature [data] present in test data point [True]
# 28 Text feature [phosphorylation] present in test data point [True]
# 29 Text feature [analysis] present in test data point [True]
# 30 Text feature [gene] present in test data point [True]
# 31 Text feature [two] present in test data point [True]
# 32 Text feature [may] present in test data point [True]
# 33 Text feature [table] present in test data point [True]
# 34 Text feature [treatment] present in test data point [True]
# 35 Text feature [shown] present in test data point [True]
# 36 Text feature [results] present in test data point [True]
# 37 Text feature [identified] present in test data point [True]
# 38 Text feature [lines] present in test data point [True]
# 39 Text feature [found] present in test data point [True]
# 40 Text feature [receptor] present in test data point [True]
# 41 Text feature [wild] present in test data point [True]
# 42 Text feature [expressing] present in test data point [True]
# 43 Text feature [inhibitors] present in test data point [True]
# 44 Text feature [tyrosine] present in test data point [True]
# 45 Text feature [clinical] present in test data point [True]
# 46 Text feature [binding] present in test data point [True]
# 47 Text feature [study] present in test data point [True]
# 48 Text feature [one] present in test data point [True]
# 49 Text feature [inhibitor] present in test data point [True]
# 51 Text feature [observed] present in test data point [True]
# 52 Text feature [associated] present in test data point [True]
# 53 Text feature [human] present in test data point [True]
# 54 Text feature [dna] present in test data point [True]
# 55 Text feature [showed] present in test data point [True]
# 56 Text feature [used] present in test data point [True]
# 57 Text feature [12] present in test data point [True]
# 58 Text feature [activating] present in test data point [True]
# 59 Text feature [wt] present in test data point [True]
# 60 Text feature [well] present in test data point [True]
# 61 Text feature [pathway] present in test data point [True]
# 63 Text feature [previously] present in test data point [True]
# 66 Text feature [however] present in test data point [True]
# 68 Text feature [20] present in test data point [True]
# 69 Text feature [reported] present in test data point [True]
# 70 Text feature [studies] present in test data point [True]
# 71 Text feature [three] present in test data point [True]
# 72 Text feature [akt] present in test data point [True]
# 73 Text feature [inhibition] present in test data point [True]
# 74 Text feature [lung] present in test data point [True]
# 75 Text feature [genes] present in test data point [True]
# 76 Text feature [ras] present in test data point [True]
# 77 Text feature [different] present in test data point [True]
# 78 Text feature [patient] present in test data point [True]
# 79 Text feature [levels] present in test data point [True]
# 80 Text feature [response] present in test data point [True]
# 81 Text feature [compared] present in test data point [True]
# 82 Text feature [described] present in test data point [True]
# 83 Text feature [activated] present in test data point [True]
# 84 Text feature [proliferation] present in test data point [True]
# 86 Text feature [survival] present in test data point [True]
# 87 Text feature [15] present in test data point [True]
# 88 Text feature [14] present in test data point [True]
# 89 Text feature [increased] present in test data point [True]
# 90 Text feature [oncogenic] present in test data point [True]
# 91 Text feature [specific] present in test data point [True]
# 92 Text feature [11] present in test data point [True]
# 93 Text feature [cases] present in test data point [True]
# 94 Text feature [sequencing] present in test data point [True]
# 95 Text feature [samples] present in test data point [True]
# 96 Text feature [proteins] present in test data point [True]
# 97 Text feature [including] present in test data point [True]
# 98 Text feature [presence] present in test data point [True]
# 99 Text feature [similar] present in test data point [True]
# Out of the top  100  features  94 are present in query point

# %% [markdown]
# ## KNN On Tfidf

# %%
#hyperparameter tuning
alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_responseCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_responseCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 5
# Log Loss : 1.333662707343848
# for alpha = 11
# Log Loss : 1.3090468867381335
# for alpha = 15
# Log Loss : 1.295451782830171
# for alpha = 21
# Log Loss : 1.2845944924604813
# for alpha = 31
# Log Loss : 1.283626650515353
# for alpha = 41
# Log Loss : 1.3032433668884456
# for alpha = 51
# Log Loss : 1.3334474953622857
# for alpha = 99
# Log Loss : 1.3248534957728655
# For values of best alpha =  31 The train log loss is: 1.1202665862481622
# For values of best alpha =  31 The cross validation log loss is: 1.283626650515353
# For values of best alpha =  31 The test log loss is: 1.2919793642759905

# %%
#fitting best model
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y, cv_x_responseCoding, cv_y, clf)
# Out:
# Log loss : 1.283626650515353
# Number of mis-classified points : 0.46616541353383456
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
# sample query point1
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_responseCoding[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 7
# The  31  nearest neighbours of the test points belongs to classes [7 7 2 7 7 7 7 7 2 2 2 2 5 7 7 7 3 7 7 7 7 7 7 2 7 2 7 2 2 7 7]
# Fequency of nearest points : Counter({7: 20, 2: 9, 5: 1, 3: 1})

# %%
#sample point 2
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 10
predicted_cls = sig_clf.predict(test_x_responseCoding[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 5
# The  31  nearest neighbours of the test points belongs to classes [6 1 6 4 4 1 1 4 1 4 1 5 1 4 6 1 6 8 4 8 1 6 1 1 6 6 5 4 1 6 1]
# Fequency of nearest points : Counter({1: 12, 6: 8, 4: 7, 5: 2, 8: 2})

# %% [markdown]
# ## Logistic Regression with TFIDF (With Balencing)

# %%
train_x_onehotCoding = train_x_onehotCoding2
test_x_onehotCoding = test_x_onehotCoding2
cv_x_onehotCoding = cv_x_onehotCoding2


alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=120)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.0628927598186382
# for alpha = 1e-05
# Log Loss : 1.0605076248066865
# for alpha = 0.0001
# Log Loss : 1.0397655892603086
# for alpha = 0.001
# Log Loss : 0.9328946361744184
# for alpha = 0.01
# Log Loss : 1.0281339677570138
# for alpha = 0.1
# Log Loss : 1.444066673250846
# for alpha = 1
# Log Loss : 1.7513471540790944
# for alpha = 10
# Log Loss : 1.7898068233601667
# for alpha = 100
# Log Loss : 1.7932962183035652
# For values of best alpha =  0.001 The train log loss is: 0.6004276696995929
# For values of best alpha =  0.001 The cross validation log loss is: 0.9228824672333061
# For values of best alpha =  0.001 The test log loss is: 0.956364605944302

# %%
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 0.9328946361744184
# Number of mis-classified points : 0.32142857142857145
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
## correctly classified point
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0163 0.0497 0.0207 0.0096 0.0367 0.0204 0.8377 0.0047 0.0042]]
# Actual Class : 7
# --------------------------------------------------
# 2 Text feature [activating] present in test data point [True]
# 3 Text feature [constitutive] present in test data point [True]
# 9 Text feature [activation] present in test data point [True]
# 13 Text feature [kinase] present in test data point [True]
# 20 Text feature [downstream] present in test data point [True]
# 22 Text feature [codon] present in test data point [True]
# 25 Text feature [phosphorylation] present in test data point [True]
# 26 Text feature [expressing] present in test data point [True]
# 29 Text feature [tyr] present in test data point [True]
# 31 Text feature [ba] present in test data point [True]
# 45 Text feature [amplification] present in test data point [True]
# 46 Text feature [f3] present in test data point [True]
# 59 Text feature [receptor] present in test data point [True]
# 74 Text feature [signaling] present in test data point [True]
# 77 Text feature [phosphorylated] present in test data point [True]
# 92 Text feature [tyrosine] present in test data point [True]
# 94 Text feature [stat3] present in test data point [True]
# 99 Text feature [account] present in test data point [True]
# 101 Text feature [codons] present in test data point [True]
# 104 Text feature [useful] present in test data point [True]
# 110 Text feature [ligand] present in test data point [True]
# 116 Text feature [slightly] present in test data point [True]
# 118 Text feature [driven] present in test data point [True]
# 121 Text feature [nucleotide] present in test data point [True]
# 124 Text feature [nr] present in test data point [True]
# 130 Text feature [pdgfra] present in test data point [True]
# 132 Text feature [transiently] present in test data point [True]
# 136 Text feature [malignant] present in test data point [True]
# 145 Text feature [gists] present in test data point [True]
# 149 Text feature [mutants] present in test data point [True]
# 152 Text feature [inhibited] present in test data point [True]
# 155 Text feature [genomic] present in test data point [True]
# 158 Text feature [absence] present in test data point [True]
# 161 Text feature [rac] present in test data point [True]
# 164 Text feature [d816v] present in test data point [True]
# 166 Text feature [extracellular] present in test data point [True]
# 167 Text feature [oncogenic] present in test data point [True]
# 169 Text feature [spectrum] present in test data point [True]
# 172 Text feature [er] present in test data point [True]
# 178 Text feature [triphosphate] present in test data point [True]
# 182 Text feature [minutes] present in test data point [True]
# 194 Text feature [120] present in test data point [True]
# 197 Text feature [morphology] present in test data point [True]
# 203 Text feature [serum] present in test data point [True]
# 209 Text feature [product] present in test data point [True]
# 221 Text feature [oncoproteins] present in test data point [True]
# 225 Text feature [open] present in test data point [True]
# 227 Text feature [institutional] present in test data point [True]
# 228 Text feature [pathways] present in test data point [True]
# 233 Text feature [origin] present in test data point [True]
# 235 Text feature [signals] present in test data point [True]
# 242 Text feature [example] present in test data point [True]
# 245 Text feature [adjacent] present in test data point [True]
# 250 Text feature [sensitive] present in test data point [True]
# 265 Text feature [clone] present in test data point [True]
# 266 Text feature [leukemia] present in test data point [True]
# 292 Text feature [nih] present in test data point [True]
# 303 Text feature [phosphotyrosine] present in test data point [True]
# 304 Text feature [cho] present in test data point [True]
# 310 Text feature [immunohistochemistry] present in test data point [True]
# 318 Text feature [tk] present in test data point [True]
# 322 Text feature [transient] present in test data point [True]
# 329 Text feature [respect] present in test data point [True]
# 350 Text feature [diagnosis] present in test data point [True]
# 365 Text feature [work] present in test data point [True]
# 370 Text feature [corp] present in test data point [True]
# 373 Text feature [fusion] present in test data point [True]
# 377 Text feature [advanced] present in test data point [True]
# 384 Text feature [minute] present in test data point [True]
# 385 Text feature [oncology] present in test data point [True]
# 395 Text feature [fig] present in test data point [True]
# 402 Text feature [effective] present in test data point [True]
# 403 Text feature [occur] present in test data point [True]
# 423 Text feature [gastrointestinal] present in test data point [True]
# 437 Text feature [amplified] present in test data point [True]
# 450 Text feature [105] present in test data point [True]
# 465 Text feature [approximately] present in test data point [True]
# 467 Text feature [express] present in test data point [True]
# 484 Text feature [threonine] present in test data point [True]
# 489 Text feature [immunoblotting] present in test data point [True]
# 495 Text feature [examples] present in test data point [True]
# 499 Text feature [stably] present in test data point [True]
# Out of the top  500  features  82 are present in query point

# %%
#incorrectly classified point
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 5
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.1425 0.2355 0.0188 0.046  0.0661 0.1317 0.3476 0.0076 0.0042]]
# Actual Class : 2
# --------------------------------------------------
# 9 Text feature [activation] present in test data point [True]
# 10 Text feature [intrinsic] present in test data point [True]
# 13 Text feature [kinase] present in test data point [True]
# 26 Text feature [expressing] present in test data point [True]
# 28 Text feature [cancers] present in test data point [True]
# 36 Text feature [transformed] present in test data point [True]
# 37 Text feature [oncogene] present in test data point [True]
# 45 Text feature [amplification] present in test data point [True]
# 47 Text feature [virus] present in test data point [True]
# 54 Text feature [oncogenes] present in test data point [True]
# 59 Text feature [receptor] present in test data point [True]
# 60 Text feature [lung] present in test data point [True]
# 74 Text feature [signaling] present in test data point [True]
# 79 Text feature [rarely] present in test data point [True]
# 99 Text feature [account] present in test data point [True]
# 103 Text feature [immune] present in test data point [True]
# 110 Text feature [ligand] present in test data point [True]
# 121 Text feature [nucleotide] present in test data point [True]
# 122 Text feature [positive] present in test data point [True]
# 127 Text feature [kras] present in test data point [True]
# 136 Text feature [malignant] present in test data point [True]
# 138 Text feature [wt] present in test data point [True]
# 147 Text feature [overexpression] present in test data point [True]
# 149 Text feature [mutants] present in test data point [True]
# 152 Text feature [inhibited] present in test data point [True]
# 154 Text feature [viral] present in test data point [True]
# 157 Text feature [colleagues] present in test data point [True]
# 158 Text feature [absence] present in test data point [True]
# 169 Text feature [spectrum] present in test data point [True]
# 193 Text feature [lesions] present in test data point [True]
# 194 Text feature [120] present in test data point [True]
# 206 Text feature [agent] present in test data point [True]
# 208 Text feature [progressed] present in test data point [True]
# 209 Text feature [product] present in test data point [True]
# 220 Text feature [untreated] present in test data point [True]
# 232 Text feature [s7] present in test data point [True]
# 239 Text feature [must] present in test data point [True]
# 242 Text feature [example] present in test data point [True]
# 250 Text feature [sensitive] present in test data point [True]
# 257 Text feature [antigen] present in test data point [True]
# 265 Text feature [clone] present in test data point [True]
# 266 Text feature [leukemia] present in test data point [True]
# 269 Text feature [carcinoma] present in test data point [True]
# 271 Text feature [supplementary] present in test data point [True]
# 315 Text feature [mortality] present in test data point [True]
# 316 Text feature [cultured] present in test data point [True]
# 323 Text feature [follow] present in test data point [True]
# 328 Text feature [continued] present in test data point [True]
# 329 Text feature [respect] present in test data point [True]
# 330 Text feature [androgen] present in test data point [True]
# 337 Text feature [s3] present in test data point [True]
# 341 Text feature [doses] present in test data point [True]
# 346 Text feature [radiotherapy] present in test data point [True]
# 356 Text feature [united] present in test data point [True]
# 365 Text feature [work] present in test data point [True]
# 374 Text feature [scid] present in test data point [True]
# 385 Text feature [oncology] present in test data point [True]
# 395 Text feature [fig] present in test data point [True]
# 402 Text feature [effective] present in test data point [True]
# 403 Text feature [occur] present in test data point [True]
# 417 Text feature [position] present in test data point [True]
# 418 Text feature [japan] present in test data point [True]
# 431 Text feature [weeks] present in test data point [True]
# 433 Text feature [radiation] present in test data point [True]
# 434 Text feature [hour] present in test data point [True]
# 455 Text feature [reviewed] present in test data point [True]
# 461 Text feature [supports] present in test data point [True]
# 465 Text feature [approximately] present in test data point [True]
# 476 Text feature [s9] present in test data point [True]
# 490 Text feature [overexpressing] present in test data point [True]
# 499 Text feature [stably] present in test data point [True]
# Out of the top  500  features  71 are present in query point

# %% [markdown]
# ## Logistic Regression without balencing

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier( alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=120)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.06671068624848
# for alpha = 1e-05
# Log Loss : 1.0581135303373947
# for alpha = 0.0001
# Log Loss : 1.0448278228284174
# for alpha = 0.001
# Log Loss : 0.9428328737712406
# for alpha = 0.01
# Log Loss : 1.0525248145651223
# for alpha = 0.1
# Log Loss : 1.3437858072480797
# for alpha = 1
# Log Loss : 1.694952914767787
# for alpha = 10
# Log Loss : 1.7662518852542175
# for alpha = 100
# Log Loss : 1.7730063850828968
# For values of best alpha =  0.001 The train log loss is: 0.6016675620712773
# For values of best alpha =  0.001 The cross validation log loss is: 0.9369982142018976
# For values of best alpha =  0.001 The test log loss is: 0.9585622259854818

# %%
#------------------------------
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 0.9428328737712406
# Number of mis-classified points : 0.31954887218045114
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
#correctly classified point
# from tabulate import tabulate
clf = SGDClassifier( alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0163 0.0497 0.0207 0.0096 0.0367 0.0204 0.8377 0.0047 0.0042]]
# Actual Class : 7
# --------------------------------------------------
# 2 Text feature [activating] present in test data point [True]
# 3 Text feature [constitutive] present in test data point [True]
# 9 Text feature [activation] present in test data point [True]
# 13 Text feature [kinase] present in test data point [True]
# 20 Text feature [downstream] present in test data point [True]
# 22 Text feature [codon] present in test data point [True]
# 25 Text feature [phosphorylation] present in test data point [True]
# 26 Text feature [expressing] present in test data point [True]
# 29 Text feature [tyr] present in test data point [True]
# 31 Text feature [ba] present in test data point [True]
# 45 Text feature [amplification] present in test data point [True]
# 46 Text feature [f3] present in test data point [True]
# 59 Text feature [receptor] present in test data point [True]
# 74 Text feature [signaling] present in test data point [True]
# 77 Text feature [phosphorylated] present in test data point [True]
# 92 Text feature [tyrosine] present in test data point [True]
# 94 Text feature [stat3] present in test data point [True]
# 99 Text feature [account] present in test data point [True]
# 101 Text feature [codons] present in test data point [True]
# 104 Text feature [useful] present in test data point [True]
# 110 Text feature [ligand] present in test data point [True]
# 116 Text feature [slightly] present in test data point [True]
# 118 Text feature [driven] present in test data point [True]
# 121 Text feature [nucleotide] present in test data point [True]
# 124 Text feature [nr] present in test data point [True]
# 130 Text feature [pdgfra] present in test data point [True]
# 132 Text feature [transiently] present in test data point [True]
# 136 Text feature [malignant] present in test data point [True]
# 145 Text feature [gists] present in test data point [True]
# 149 Text feature [mutants] present in test data point [True]
# 152 Text feature [inhibited] present in test data point [True]
# 155 Text feature [genomic] present in test data point [True]
# 158 Text feature [absence] present in test data point [True]
# 161 Text feature [rac] present in test data point [True]
# 164 Text feature [d816v] present in test data point [True]
# 166 Text feature [extracellular] present in test data point [True]
# 167 Text feature [oncogenic] present in test data point [True]
# 169 Text feature [spectrum] present in test data point [True]
# 172 Text feature [er] present in test data point [True]
# 178 Text feature [triphosphate] present in test data point [True]
# 182 Text feature [minutes] present in test data point [True]
# 194 Text feature [120] present in test data point [True]
# 197 Text feature [morphology] present in test data point [True]
# 203 Text feature [serum] present in test data point [True]
# 209 Text feature [product] present in test data point [True]
# 221 Text feature [oncoproteins] present in test data point [True]
# 225 Text feature [open] present in test data point [True]
# 227 Text feature [institutional] present in test data point [True]
# 228 Text feature [pathways] present in test data point [True]
# 233 Text feature [origin] present in test data point [True]
# 235 Text feature [signals] present in test data point [True]
# 242 Text feature [example] present in test data point [True]
# 245 Text feature [adjacent] present in test data point [True]
# 250 Text feature [sensitive] present in test data point [True]
# 265 Text feature [clone] present in test data point [True]
# 266 Text feature [leukemia] present in test data point [True]
# 292 Text feature [nih] present in test data point [True]
# 303 Text feature [phosphotyrosine] present in test data point [True]
# 304 Text feature [cho] present in test data point [True]
# 310 Text feature [immunohistochemistry] present in test data point [True]
# 318 Text feature [tk] present in test data point [True]
# 322 Text feature [transient] present in test data point [True]
# 329 Text feature [respect] present in test data point [True]
# 350 Text feature [diagnosis] present in test data point [True]
# 365 Text feature [work] present in test data point [True]
# 370 Text feature [corp] present in test data point [True]
# 373 Text feature [fusion] present in test data point [True]
# 377 Text feature [advanced] present in test data point [True]
# 384 Text feature [minute] present in test data point [True]
# 385 Text feature [oncology] present in test data point [True]
# 395 Text feature [fig] present in test data point [True]
# 402 Text feature [effective] present in test data point [True]
# 403 Text feature [occur] present in test data point [True]
# 423 Text feature [gastrointestinal] present in test data point [True]
# 437 Text feature [amplified] present in test data point [True]
# 450 Text feature [105] present in test data point [True]
# 465 Text feature [approximately] present in test data point [True]
# 467 Text feature [express] present in test data point [True]
# 484 Text feature [threonine] present in test data point [True]
# 489 Text feature [immunoblotting] present in test data point [True]
# 495 Text feature [examples] present in test data point [True]
# 499 Text feature [stably] present in test data point [True]
# Out of the top  500  features  82 are present in query point

# %%
#incorrectly classified point
# from tabulate import tabulate
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 5
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.1425 0.2355 0.0188 0.046  0.0661 0.1317 0.3476 0.0076 0.0042]]
# Actual Class : 2
# --------------------------------------------------
# 9 Text feature [activation] present in test data point [True]
# 12 Text feature [kinase] present in test data point [True]
# 15 Text feature [intrinsic] present in test data point [True]
# 22 Text feature [expressing] present in test data point [True]
# 28 Text feature [cancers] present in test data point [True]
# 44 Text feature [transformed] present in test data point [True]
# 47 Text feature [oncogene] present in test data point [True]
# 52 Text feature [mutants] present in test data point [True]
# 53 Text feature [signaling] present in test data point [True]
# 55 Text feature [virus] present in test data point [True]
# 75 Text feature [rarely] present in test data point [True]
# 77 Text feature [oncogenes] present in test data point [True]
# 84 Text feature [wt] present in test data point [True]
# 92 Text feature [receptor] present in test data point [True]
# 93 Text feature [fig] present in test data point [True]
# 97 Text feature [lung] present in test data point [True]
# 102 Text feature [amplification] present in test data point [True]
# 104 Text feature [positive] present in test data point [True]
# 106 Text feature [immune] present in test data point [True]
# 125 Text feature [supplementary] present in test data point [True]
# 131 Text feature [ligand] present in test data point [True]
# 134 Text feature [account] present in test data point [True]
# 139 Text feature [nucleotide] present in test data point [True]
# 148 Text feature [inhibited] present in test data point [True]
# 155 Text feature [spectrum] present in test data point [True]
# 160 Text feature [clone] present in test data point [True]
# 175 Text feature [absence] present in test data point [True]
# 179 Text feature [product] present in test data point [True]
# 183 Text feature [kras] present in test data point [True]
# 192 Text feature [overexpression] present in test data point [True]
# 209 Text feature [cells] present in test data point [True]
# 219 Text feature [120] present in test data point [True]
# 221 Text feature [mutant] present in test data point [True]
# 222 Text feature [colleagues] present in test data point [True]
# 230 Text feature [viral] present in test data point [True]
# 232 Text feature [example] present in test data point [True]
# 244 Text feature [must] present in test data point [True]
# 262 Text feature [3a] present in test data point [True]
# 269 Text feature [s3] present in test data point [True]
# 273 Text feature [untreated] present in test data point [True]
# 274 Text feature [malignant] present in test data point [True]
# 277 Text feature [s7] present in test data point [True]
# 279 Text feature [progressed] present in test data point [True]
# 281 Text feature [carcinoma] present in test data point [True]
# 283 Text feature [sensitive] present in test data point [True]
# 285 Text feature [scid] present in test data point [True]
# 286 Text feature [leukemia] present in test data point [True]
# 296 Text feature [harboring] present in test data point [True]
# 298 Text feature [androgen] present in test data point [True]
# 302 Text feature [lesions] present in test data point [True]
# 312 Text feature [approximately] present in test data point [True]
# 321 Text feature [mortality] present in test data point [True]
# 333 Text feature [antigen] present in test data point [True]
# 337 Text feature [work] present in test data point [True]
# 354 Text feature [respect] present in test data point [True]
# 366 Text feature [agent] present in test data point [True]
# 370 Text feature [regulated] present in test data point [True]
# 375 Text feature [doses] present in test data point [True]
# 377 Text feature [continued] present in test data point [True]
# 385 Text feature [overexpressing] present in test data point [True]
# 388 Text feature [double] present in test data point [True]
# 399 Text feature [cultured] present in test data point [True]
# 410 Text feature [occur] present in test data point [True]
# 419 Text feature [radiotherapy] present in test data point [True]
# 421 Text feature [weeks] present in test data point [True]
# 430 Text feature [effective] present in test data point [True]
# 436 Text feature [proposed] present in test data point [True]
# 448 Text feature [supports] present in test data point [True]
# 449 Text feature [derived] present in test data point [True]
# 461 Text feature [reviewed] present in test data point [True]
# 466 Text feature [stably] present in test data point [True]
# 467 Text feature [s9] present in test data point [True]
# 468 Text feature [suggest] present in test data point [True]
# 469 Text feature [factors] present in test data point [True]
# 473 Text feature [radiation] present in test data point [True]
# 475 Text feature [s1] present in test data point [True]
# 480 Text feature [000] present in test data point [True]
# 488 Text feature [position] present in test data point [True]
# 492 Text feature [xenograft] present in test data point [True]
# 493 Text feature [united] present in test data point [True]
# 494 Text feature [eventually] present in test data point [True]
# Out of the top  500  features  81 are present in query point

# %% [markdown]
# ### Linear SVM on Tfidf

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.0528184479227252
# for C = 0.0001
# Log Loss : 1.0636396204751137
# for C = 0.001
# Log Loss : 1.0193386723954183
# for C = 0.01
# Log Loss : 1.049977661350602
# for C = 0.1
# Log Loss : 1.4086143798005974
# for C = 1
# Log Loss : 1.753574927346725
# for C = 10
# Log Loss : 1.7937153659497667
# for C = 100
# Log Loss : 1.793716338596364
# For values of best alpha =  0.001 The train log loss is: 0.678797687740826
# For values of best alpha =  0.001 The cross validation log loss is: 1.0193386723954183
# For values of best alpha =  0.001 The test log loss is: 1.0560400361390503

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.0193386723954183
# Number of mis-classified points : 0.32894736842105265
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
#correctly classified point
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0505 0.0691 0.0181 0.0306 0.0421 0.0215 0.7605 0.0046 0.0032]]
# Actual Class : 7
# --------------------------------------------------
# 3 Text feature [mutants] present in test data point [True]
# 6 Text feature [activating] present in test data point [True]
# 9 Text feature [constitutive] present in test data point [True]
# 26 Text feature [codon] present in test data point [True]
# 27 Text feature [phosphorylation] present in test data point [True]
# 33 Text feature [expressing] present in test data point [True]
# 34 Text feature [activation] present in test data point [True]
# 35 Text feature [ba] present in test data point [True]
# 61 Text feature [f3] present in test data point [True]
# 62 Text feature [downstream] present in test data point [True]
# 72 Text feature [mutant] present in test data point [True]
# 77 Text feature [fig] present in test data point [True]
# 78 Text feature [useful] present in test data point [True]
# 86 Text feature [tyr] present in test data point [True]
# 90 Text feature [phosphorylated] present in test data point [True]
# 106 Text feature [spectrum] present in test data point [True]
# 107 Text feature [oncoproteins] present in test data point [True]
# 125 Text feature [account] present in test data point [True]
# 126 Text feature [slightly] present in test data point [True]
# 128 Text feature [driven] present in test data point [True]
# 129 Text feature [morphology] present in test data point [True]
# 131 Text feature [kinase] present in test data point [True]
# 132 Text feature [ligand] present in test data point [True]
# 161 Text feature [transiently] present in test data point [True]
# 168 Text feature [rac] present in test data point [True]
# 171 Text feature [extracellular] present in test data point [True]
# 175 Text feature [work] present in test data point [True]
# 179 Text feature [clone] present in test data point [True]
# 180 Text feature [codons] present in test data point [True]
# 182 Text feature [alternative] present in test data point [True]
# 196 Text feature [example] present in test data point [True]
# 199 Text feature [open] present in test data point [True]
# 205 Text feature [institutional] present in test data point [True]
# 206 Text feature [nucleotide] present in test data point [True]
# 211 Text feature [nr] present in test data point [True]
# 214 Text feature [origin] present in test data point [True]
# 223 Text feature [sensitive] present in test data point [True]
# 226 Text feature [nih] present in test data point [True]
# 227 Text feature [minutes] present in test data point [True]
# 228 Text feature [000] present in test data point [True]
# 230 Text feature [product] present in test data point [True]
# 246 Text feature [inhibited] present in test data point [True]
# 251 Text feature [figs] present in test data point [True]
# 253 Text feature [cells] present in test data point [True]
# 256 Text feature [proven] present in test data point [True]
# 270 Text feature [genomic] present in test data point [True]
# 271 Text feature [d842v] present in test data point [True]
# 286 Text feature [nm] present in test data point [True]
# 290 Text feature [120] present in test data point [True]
# 295 Text feature [double] present in test data point [True]
# 301 Text feature [d816v] present in test data point [True]
# 313 Text feature [stat3] present in test data point [True]
# 316 Text feature [suggest] present in test data point [True]
# 323 Text feature [cho] present in test data point [True]
# 324 Text feature [absence] present in test data point [True]
# 327 Text feature [effective] present in test data point [True]
# 329 Text feature [harboring] present in test data point [True]
# 333 Text feature [minute] present in test data point [True]
# 337 Text feature [gists] present in test data point [True]
# 342 Text feature [2005] present in test data point [True]
# 344 Text feature [triphosphate] present in test data point [True]
# 347 Text feature [various] present in test data point [True]
# 355 Text feature [express] present in test data point [True]
# 357 Text feature [signaling] present in test data point [True]
# 361 Text feature [approximately] present in test data point [True]
# 363 Text feature [arising] present in test data point [True]
# 367 Text feature [respect] present in test data point [True]
# 388 Text feature [consistent] present in test data point [True]
# 405 Text feature [immunoblotting] present in test data point [True]
# 407 Text feature [potential] present in test data point [True]
# 425 Text feature [oncology] present in test data point [True]
# 430 Text feature [relative] present in test data point [True]
# 437 Text feature [changes] present in test data point [True]
# 438 Text feature [pdgfra] present in test data point [True]
# 450 Text feature [independent] present in test data point [True]
# 457 Text feature [obtained] present in test data point [True]
# 460 Text feature [amplification] present in test data point [True]
# 472 Text feature [constructs] present in test data point [True]
# 474 Text feature [209] present in test data point [True]
# 478 Text feature [levels] present in test data point [True]
# 480 Text feature [along] present in test data point [True]
# 490 Text feature [receptor] present in test data point [True]
# 494 Text feature [interestingly] present in test data point [True]
# Out of the top  500  features  83 are present in query point

# %%
#incorrectly classified point
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 5
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.1589 0.1937 0.0164 0.0675 0.0568 0.0955 0.3999 0.0071 0.0043]]
# Actual Class : 2
# --------------------------------------------------
# 3 Text feature [mutants] present in test data point [True]
# 7 Text feature [intrinsic] present in test data point [True]
# 25 Text feature [cancers] present in test data point [True]
# 30 Text feature [transformed] present in test data point [True]
# 33 Text feature [expressing] present in test data point [True]
# 34 Text feature [activation] present in test data point [True]
# 41 Text feature [supplementary] present in test data point [True]
# 44 Text feature [rarely] present in test data point [True]
# 65 Text feature [virus] present in test data point [True]
# 72 Text feature [mutant] present in test data point [True]
# 77 Text feature [fig] present in test data point [True]
# 80 Text feature [oncogenes] present in test data point [True]
# 87 Text feature [positive] present in test data point [True]
# 91 Text feature [wt] present in test data point [True]
# 102 Text feature [s3] present in test data point [True]
# 106 Text feature [spectrum] present in test data point [True]
# 110 Text feature [oncogene] present in test data point [True]
# 115 Text feature [s1] present in test data point [True]
# 125 Text feature [account] present in test data point [True]
# 127 Text feature [3a] present in test data point [True]
# 131 Text feature [kinase] present in test data point [True]
# 132 Text feature [ligand] present in test data point [True]
# 175 Text feature [work] present in test data point [True]
# 176 Text feature [proposed] present in test data point [True]
# 179 Text feature [clone] present in test data point [True]
# 188 Text feature [regulated] present in test data point [True]
# 195 Text feature [s7] present in test data point [True]
# 196 Text feature [example] present in test data point [True]
# 206 Text feature [nucleotide] present in test data point [True]
# 212 Text feature [immune] present in test data point [True]
# 216 Text feature [carcinoma] present in test data point [True]
# 219 Text feature [factors] present in test data point [True]
# 223 Text feature [sensitive] present in test data point [True]
# 228 Text feature [000] present in test data point [True]
# 230 Text feature [product] present in test data point [True]
# 234 Text feature [radiotherapy] present in test data point [True]
# 237 Text feature [note] present in test data point [True]
# 246 Text feature [inhibited] present in test data point [True]
# 251 Text feature [figs] present in test data point [True]
# 253 Text feature [cells] present in test data point [True]
# 258 Text feature [doses] present in test data point [True]
# 259 Text feature [must] present in test data point [True]
# 264 Text feature [colleagues] present in test data point [True]
# 267 Text feature [agent] present in test data point [True]
# 278 Text feature [viral] present in test data point [True]
# 282 Text feature [reviewed] present in test data point [True]
# 287 Text feature [52] present in test data point [True]
# 290 Text feature [120] present in test data point [True]
# 292 Text feature [androgen] present in test data point [True]
# 295 Text feature [double] present in test data point [True]
# 298 Text feature [overexpression] present in test data point [True]
# 314 Text feature [heterogeneous] present in test data point [True]
# 316 Text feature [suggest] present in test data point [True]
# 318 Text feature [untreated] present in test data point [True]
# 324 Text feature [absence] present in test data point [True]
# 325 Text feature [continued] present in test data point [True]
# 326 Text feature [plasma] present in test data point [True]
# 327 Text feature [effective] present in test data point [True]
# 329 Text feature [harboring] present in test data point [True]
# 331 Text feature [overexpressing] present in test data point [True]
# 339 Text feature [form] present in test data point [True]
# 341 Text feature [adjusted] present in test data point [True]
# 347 Text feature [various] present in test data point [True]
# 356 Text feature [united] present in test data point [True]
# 357 Text feature [signaling] present in test data point [True]
# 361 Text feature [approximately] present in test data point [True]
# 363 Text feature [arising] present in test data point [True]
# 365 Text feature [progressed] present in test data point [True]
# 367 Text feature [respect] present in test data point [True]
# 371 Text feature [renal] present in test data point [True]
# 388 Text feature [consistent] present in test data point [True]
# 397 Text feature [blood] present in test data point [True]
# 404 Text feature [driving] present in test data point [True]
# 407 Text feature [potential] present in test data point [True]
# 408 Text feature [regression] present in test data point [True]
# 417 Text feature [follow] present in test data point [True]
# 425 Text feature [oncology] present in test data point [True]
# 430 Text feature [relative] present in test data point [True]
# 434 Text feature [identical] present in test data point [True]
# 437 Text feature [changes] present in test data point [True]
# 445 Text feature [eventually] present in test data point [True]
# 449 Text feature [heterogeneity] present in test data point [True]
# 450 Text feature [independent] present in test data point [True]
# 452 Text feature [five] present in test data point [True]
# 457 Text feature [obtained] present in test data point [True]
# 459 Text feature [s9] present in test data point [True]
# 460 Text feature [amplification] present in test data point [True]
# 478 Text feature [levels] present in test data point [True]
# 480 Text feature [along] present in test data point [True]
# 485 Text feature [paradigm] present in test data point [True]
# 489 Text feature [radiation] present in test data point [True]
# 490 Text feature [receptor] present in test data point [True]
# 494 Text feature [interestingly] present in test data point [True]
# Out of the top  500  features  93 are present in query point

# %% [markdown]
# ## Random Forest on Tfidf

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 


best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.2386493179584814
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.1402812828997457
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.2148997466283835
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.136043602961679
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.2082054752043778
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.134796722206157
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.2054687907311625
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.1340439007838952
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.2033552464597708
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.1306946309181878
# For values of best estimator =  2000 The train log loss is: 0.7136542896836092
# For values of best estimator =  2000 The cross validation log loss is: 1.1306946310902077
# For values of best estimator =  2000 The test log loss is: 1.0794517088435618

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.1306946309181878
# Number of mis-classified points : 0.37406015037593987
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0379 0.1085 0.0167 0.0261 0.0387 0.0263 0.7368 0.0044 0.0048]]
# Actual Class : 7
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [tyrosine] present in test data point [True]
# 2 Text feature [activating] present in test data point [True]
# 3 Text feature [inhibitors] present in test data point [True]
# 4 Text feature [treatment] present in test data point [True]
# 6 Text feature [activation] present in test data point [True]
# 7 Text feature [inhibitor] present in test data point [True]
# 9 Text feature [phosphorylation] present in test data point [True]
# 10 Text feature [kinases] present in test data point [True]
# 11 Text feature [constitutive] present in test data point [True]
# 12 Text feature [advanced] present in test data point [True]
# 16 Text feature [treated] present in test data point [True]
# 17 Text feature [growth] present in test data point [True]
# 18 Text feature [oncogenic] present in test data point [True]
# 20 Text feature [receptor] present in test data point [True]
# 22 Text feature [therapy] present in test data point [True]
# 24 Text feature [signaling] present in test data point [True]
# 25 Text feature [inhibited] present in test data point [True]
# 32 Text feature [trials] present in test data point [True]
# 34 Text feature [protein] present in test data point [True]
# 35 Text feature [downstream] present in test data point [True]
# 37 Text feature [therapeutic] present in test data point [True]
# 39 Text feature [response] present in test data point [True]
# 41 Text feature [expressing] present in test data point [True]
# 43 Text feature [drug] present in test data point [True]
# 44 Text feature [effective] present in test data point [True]
# 48 Text feature [amplification] present in test data point [True]
# 49 Text feature [clinical] present in test data point [True]
# 52 Text feature [phosphorylated] present in test data point [True]
# 56 Text feature [extracellular] present in test data point [True]
# 60 Text feature [resistant] present in test data point [True]
# 61 Text feature [patients] present in test data point [True]
# 62 Text feature [predicted] present in test data point [True]
# 63 Text feature [resistance] present in test data point [True]
# 68 Text feature [cell] present in test data point [True]
# 69 Text feature [imatinib] present in test data point [True]
# 70 Text feature [serum] present in test data point [True]
# 72 Text feature [cells] present in test data point [True]
# 73 Text feature [harboring] present in test data point [True]
# 74 Text feature [ba] present in test data point [True]
# 75 Text feature [respond] present in test data point [True]
# 76 Text feature [potential] present in test data point [True]
# 79 Text feature [progression] present in test data point [True]
# 80 Text feature [survival] present in test data point [True]
# 81 Text feature [proteins] present in test data point [True]
# 83 Text feature [kit] present in test data point [True]
# 86 Text feature [ic50] present in test data point [True]
# 87 Text feature [sensitive] present in test data point [True]
# 88 Text feature [patient] present in test data point [True]
# 89 Text feature [proliferation] present in test data point [True]
# 91 Text feature [trial] present in test data point [True]
# 93 Text feature [dna] present in test data point [True]
# 94 Text feature [acquired] present in test data point [True]
# 96 Text feature [ligand] present in test data point [True]
# 98 Text feature [benefit] present in test data point [True]
# Out of the top  100  features  55 are present in query point

# %%
# test_point_index = 10
best_alpha = 5
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 6
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.1979 0.0658 0.0239 0.3432 0.1063 0.0426 0.0808 0.0084 0.1312]]
# Actual Class : 4
# --------------------------------------------------
# 8 Text feature [missense] present in test data point [True]
# 19 Text feature [function] present in test data point [True]
# 23 Text feature [signaling] present in test data point [True]
# 25 Text feature [loss] present in test data point [True]
# 31 Text feature [protein] present in test data point [True]
# 43 Text feature [variants] present in test data point [True]
# 44 Text feature [cells] present in test data point [True]
# 47 Text feature [expressing] present in test data point [True]
# 55 Text feature [patients] present in test data point [True]
# 60 Text feature [active] present in test data point [True]
# 61 Text feature [sensitive] present in test data point [True]
# 63 Text feature [retained] present in test data point [True]
# 72 Text feature [expected] present in test data point [True]
# 76 Text feature [cell] present in test data point [True]
# 78 Text feature [lines] present in test data point [True]
# 79 Text feature [dna] present in test data point [True]
# 99 Text feature [affected] present in test data point [True]
# Out of the top  100  features  17 are present in query point

# %% [markdown]
# ## Stacking model on Tfidf

# %%
clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 0.93
# Support vector machines : Log Loss: 1.75
# Naive Bayes : Log Loss: 1.21
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.179
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 2.041
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.524
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.064
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 0.998
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.035

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.7148019418614234
# Log loss (CV) on the stacking classifier : 1.064037446738505
# Log loss (test) on the stacking classifier : 1.0626647901294637
# Number of missclassified point : 0.3473684210526316
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# ## Maximum Voting Classifier on Tfidf

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the VotingClassifier : 0.9193931588153711
# Log loss (CV) on the VotingClassifier : 1.1622597836984263
# Log loss (test) on the VotingClassifier : 1.1866374978192589
# Number of missclassified point : 0.3458646616541353
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # Bigram models

# %% [markdown]
# ## Logistic Regression on Bigram (balenced)

# %%
train_x_onehotCoding =train_x_onehotCoding3
test_x_onehotCoding=test_x_onehotCoding3
cv_x_onehotCoding=cv_x_onehotCoding3


alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.5589517651691862
# for alpha = 1e-05
# Log Loss : 1.543714233797267
# for alpha = 0.0001
# Log Loss : 1.5434952927179721
# for alpha = 0.001
# Log Loss : 1.4678694282107245
# for alpha = 0.01
# Log Loss : 1.1765357291819705
# for alpha = 0.1
# Log Loss : 1.2269326496799766
# for alpha = 1
# Log Loss : 1.3141244096459335
# for alpha = 10
# Log Loss : 1.388633032249097
# for alpha = 100
# Log Loss : 1.4057879827873678
# For values of best alpha =  0.01 The train log loss is: 0.8454702802798054
# For values of best alpha =  0.01 The cross validation log loss is: 1.1765357291819705
# For values of best alpha =  0.01 The test log loss is: 1.152278548629367

# %%
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.1765357291819705
# Number of mis-classified points : 0.40601503759398494
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer(ngram_range=(1,2))
    var_count_vec = CountVectorizer(ngram_range=(1,2))
    text_count_vec = CountVectorizer(min_df=3,ngram_range=(1,2))
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %%
#incorrectly classified point
clf = SGDClassifier(class_weight='balanced' ,alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 5
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.1818 0.1696 0.0198 0.1401 0.0686 0.0453 0.3587 0.0075 0.0085]]
# Actual Class : 2
# --------------------------------------------------
# 372 Text feature [oncogene] present in test data point [True]
# Out of the top  500  features  1 are present in query point

# %%
#correctly classiffied
clf = SGDClassifier(class_weight='balanced' ,alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0433 0.0673 0.0056 0.0277 0.0277 0.0124 0.8048 0.0056 0.0055]]
# Actual Class : 7
# --------------------------------------------------
# 293 Text feature [lasota] present in test data point [True]
# Out of the top  500  features  1 are present in query point

# %% [markdown]
# ## Logistic Regression on ngram Bow (without balencing)

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.4887041085407409
# for alpha = 1e-05
# Log Loss : 1.492479692100724
# for alpha = 0.0001
# Log Loss : 1.48522827913436
# for alpha = 0.001
# Log Loss : 1.4469098194617627
# for alpha = 0.01
# Log Loss : 1.2416342349942564
# for alpha = 0.1
# Log Loss : 1.264864687347487
# for alpha = 1
# Log Loss : 1.382014121963652
# For values of best alpha =  0.01 The train log loss is: 0.8575490277643246
# For values of best alpha =  0.01 The cross validation log loss is: 1.2416342349942564
# For values of best alpha =  0.01 The test log loss is: 1.1720987340992308

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.2416342349942564
# Number of mis-classified points : 0.40225563909774437
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
#correctly classiffied
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[5.280e-02 7.160e-02 6.900e-03 3.700e-02 2.530e-02 1.160e-02 7.883e-01
#   5.700e-03 7.000e-04]]
# Actual Class : 7
# --------------------------------------------------
# 229 Text feature [lasota] present in test data point [True]
# Out of the top  500  features  1 are present in query point

# %%
#incorrectly classiffied
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 15
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 5
# Predicted Class Probabilities: [[0.1445 0.0899 0.0078 0.2366 0.3381 0.093  0.0802 0.0095 0.0004]]
# Actual Class : 5
# --------------------------------------------------
# Out of the top  500  features  0 are present in query point

# %% [markdown]
# # Conclusion

# %% [markdown]
# -  Given 3 features 'Gene', 'Variation' and 'TEXT' we have to determine which 'Class' it belongs to.
# -  As per business constrains we have no latency requirement.But our model should have less error.Also Interpretability is important.
# -  We begin with applying bow vectorization on features and compared its perfomanve with naive bayes,knn,logistic regression,randomforest,stacking model and voting model.Eventhough the last 2 models have less inyerpretability we just tried using that.Out of that logistic regression was giving better results.
# -  We also tried responce coding of features and fitted it to a randomforest model.
# -  Then inorder to improve perfomance we introduced some feature engineering and tried with tfidf vector for encoding.Ultimatly we got better result with logistic regression.

# %%
from prettytable import PrettyTable
table = PrettyTable(['Model', 'Vector', 'Train Loss', 'CV loss', 'Test loss', 'Mis-classification'])
table.add_row(['Naive Bayes', 'Bow',0.90,1.25,1.25,0.39])
table.add_row(['k-NN', 'Bow',1.12,1.28,1.29,0.46])
table.add_row(['Logistic Regression(Balanced)', 'Bow',0.65,1.08,1.08,0.36])
table.add_row(['Logistic Regression(Balanced)', 'Bigram',0.84,1.17,1.15,0.40])
table.add_row(['Logistic Regression(Imbalanced)', 'Bow',0.66,1.15,1.09,0.36])
table.add_row(['Logistic Regression(Imbalanced)', 'Bigram',0.85,1.24,1.17,0.40])
table.add_row(['Linear SVM', 'Bow',0.78,1.14,1.15,0.36])
table.add_row(['Random Forest(One Hot)', 'Bow',0.73,1.18,1.15,0.38 ])
table.add_row(['Random Forest(Response coding)', 'Response coding',0.69,1.03,1.07,0.37])
table.add_row(['Stacking', 'Bow',0.72,1.16,1.11,0.36])
table.add_row(['Voting', 'Bow', 0.93,1.19,1.20,0.35])
table.add_row(['Naive Bayes', 'TFIDF', 0.85,1.20,1.20,0.35])
table.add_row(['k-NN', 'TFIDF', 1.12,1.28,1.29,0.46])
table.add_row(['Logistic Regression(Balanced)', 'TFIDF',0.60,0.92,0.95,0.32])
table.add_row(['Logistic Regression(Imbalanced)', 'TFIDF',0.60,0.93,0.95,0.31])
table.add_row(['Linear SVM', 'TFIDF',0.67,1.01,1.05,0.32])
table.add_row(['Random Forest(One Hot)', 'TFIDF',0.71,1.13,1.07,0.37])
table.add_row(['Stacking', 'TFIDF',0.71,1.06,1.06,0.34])
table.add_row(['Voting', 'TFIDF', 0.91,1.16,1.18,0.34])

print(table)
# Out:
# +---------------------------------+-----------------+------------+---------+-----------+--------------------+
# |              Model              |      Vector     | Train Loss | CV loss | Test loss | Mis-classification |
# +---------------------------------+-----------------+------------+---------+-----------+--------------------+
# |           Naive Bayes           |       Bow       |    0.9     |   1.25  |    1.25   |        0.39        |
# |               k-NN              |       Bow       |    1.12    |   1.28  |    1.29   |        0.46        |
# |  Logistic Regression(Balanced)  |       Bow       |    0.65    |   1.08  |    1.08   |        0.36        |
# |  Logistic Regression(Balanced)  |      Bigram     |    0.84    |   1.17  |    1.15   |        0.4         |
# | Logistic Regression(Imbalanced) |       Bow       |    0.66    |   1.15  |    1.09   |        0.36        |
# | Logistic Regression(Imbalanced) |      Bigram     |    0.85    |   1.24  |    1.17   |        0.4         |
# |            Linear SVM           |       Bow       |    0.78    |   1.14  |    1.15   |        0.36        |
# |      Random Forest(One Hot)     |       Bow       |    0.73    |   1.18  |    1.15   |        0.38        |
# |  Random Forest(Response coding) | Response coding |    0.69    |   1.03  |    1.07   |        0.37        |
# |             Stacking            |       Bow       |    0.72    |   1.16  |    1.11   |        0.36        |
# |              Voting             |       Bow       |    0.93    |   1.19  |    1.2    |        0.35        |
# |           Naive Bayes           |      TFIDF      |    0.85    |   1.2   |    1.2    |        0.35        |
# |               k-NN              |      TFIDF      |    1.12    |   1.28  |    1.29   |        0.46        |
# |  Logistic Regression(Balanced)  |      TFIDF      |    0.6     |   0.92  |    0.95   |        0.32        |
# | Logistic Regression(Imbalanced) |      TFIDF      |    0.6     |   0.93  |    0.95   |        0.31        |
# |            Linear SVM           |      TFIDF      |    0.67    |   1.01  |    1.05   |        0.32        |
# |      Random Forest(One Hot)     |      TFIDF      |    0.71    |   1.13  |    1.07   |        0.37        |
# |             Stacking            |      TFIDF      |    0.71    |   1.06  |    1.06   |        0.34        |
# |              Voting             |      TFIDF      |    0.91    |   1.16  |    1.18   |        0.34        |
# +---------------------------------+-----------------+------------+---------+-----------+--------------------+
